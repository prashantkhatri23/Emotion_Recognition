# %% [markdown]
# ## Loading Libraries and Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# UPDATE THE MAIN DIRECTORY LOCATION ACCORDINGLY
main_dir = '/content/drive/MyDrive/IITB_EE/CS772_project/'

# %%
from IPython.display import Audio, display
import os
import pandas as pd
import re
import os
# import opensmile
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torchaudio
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pickle
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_sequence
import random
# Set the random seed
random.seed(42)

# %%
# !unzip '/content/drive/MyDrive/IITB_EE/CS772_project/IEMOCAP.zip'
# # Change directory to the root folder
# os.chdir('/content/IEMOCAP')
# # List the contents of the root folder
# !ls

# %%
# # save the DataFrame to a pickle file
# data.to_pickle('data_processed.pickle')
data_pickel_path = os.path.join(main_dir,'data_processed.pickle')
data = pd.read_pickle(data_pickel_path)
data.shape
# Out:
# (5520, 12)

# %%
data = data[(data['trans_words'] != '<s> ++GARBAGE++ </s>') & (data['trans_words'] != '<s> ++BREATHING++ </s>')].reset_index(drop=True)
data.shape
# Out:
# (5520, 12)

# %%
idx = 2
print(len(data['start_stamp'][idx].split()),data['start_stamp'][idx])
print(len(data['trans_words'][idx].split()),data['trans_words'][idx])
# Out:
# 11 0 22 34 53 82 107 152 171 200 233 273
# 11 <s> YOU KEEP SAYING MY FLASHLIGHT LIKE IT'S JUST YOURS </s>

# %%
trans_words = data['trans_words']

# %%
import re

def display_non_text(data):
    excluded_tokens = {'<s>', '</s>', '<sil>', "+"}
    non_text_samples = []
    
    for text in data:
        # Remove excluded tokens from the text
        for token in excluded_tokens:
            text = text.replace(token, '')

        non_text = re.findall(r'[^a-zA-Z\s]', text)

        if non_text:
            non_text_samples.append((text, non_text))

    return non_text_samples

non_text_samples = display_non_text(trans_words)
count_breath = 0
count_laugh = 0
count_garb = 0
print('total samples:', len(non_text_samples))
for sample, non_text in non_text_samples:
    print(f"Sample: {sample}")
    print(f"Non-text characters: {non_text}")
    print()
    if sample==" ++BREATHING++ ":
      count_breath+=1
    elif sample== " ++LAUGHTER++ ":
      count_laugh+=1
    elif sample== " ++GARBAGE++ ":
      count_garb+=1
print(f"BREATHING: {count_breath},LAUGHTER:{count_laugh},GARBAGE:{count_garb}")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Sample:  YOU'RE THE ONE WHO PROBABLY WISHES HE WAS WITH SOMEONE ELSE SOMEONE WHO  KNEW HOW TO ENJOY HERSELF AND DIDN'T TAKE EVERYTHING  SO HARD
# Non-text characters: ["'", "'"]
#
# Sample:   WELL I  GUESS  WE DON'T NEED GLASSES
# Non-text characters: ["'"]
#
# Sample:   AUGIE I'M SORRY
# Non-text characters: ["'"]
#
# Sample:  CERTAINLY IT'S  NOT  SLIGHTLY EXAGGERATED SCIENTIFIC FACT
# Non-text characters: ["'"]
#
# Sample:  WELL WE'LL SEE THEM THIS YEAR
# Non-text characters: ["'"]
#
# Sample:   YOU WERE FINE DURING THE PHONE CALL FROM MARGE  DINNER WAS OKAY  DOING THE DISHES WAS NO PROBLEM  LET'S SEE I  TOOK A SHOWER  YOU WATCHED THE NEWS YOU SAID
# Non-text characters: ["'"]
#
# Sample:  THE GRUNION ARE RUNNING TONIGHT  I SAID  GREAT LET'S GO  I FEEL LUCKY
# Non-text characters: ["'"]
#
# Sample:  OKAY SO I'M  GETTING ON MY JACKET AND  PUTTING OUT THE ANIMALS GETTING THE CAR OUT OF THE GARAGE
# Non-text characters: ["'"]
#
# Sample:   IT WAS  IN THE CAR RIGHT  DRIVING PAST THE KNICKERBOCKER LIQUOR LOCKER YOU SAID  LET'S GET SOME CHAMPAGNE AND I SAID  TIMES ARE WASTING OR SOMETHING LIKE  THAT RIGHT
# Non-text characters: ["'"]
#
# Sample:   OF  COURSE I SEE IT NOW YOU WANT THIS TO BE LIKE  THAT OTHER TIME RIGHT  THAT'S IT RIGHT
# Non-text characters: ["'"]
#
# Sample:  WELL WELCOME TO THE HUMAN RACE ALL RIGHT  DO  YOU THINK THIS IS WHAT I HAD IN MIND WHEN I PROPOSED YOU THINK  I HAD THIS GREAT FANTASY GOING THAT  FOUR YEARS DOWN THE ROAD WE'D  COME TO THE BEACH AND YELL AT EACH OTHER OVER  FISH
# Non-text characters: ["'"]
#
# Sample:  NO I KNOW  BUT STILL  I  KNOW I DON'T MAKE YOU HAPPY
# Non-text characters: ["'"]
#
# Sample:   NOW THAT YOU MENTION IT  NO I DON'T
# Non-text characters: ["'"]
#
# Sample:   I DON'T KNOW IT SEEMED LIKE A  PRETTY GOOD SPOT TO  ME  LOOK AT THE MOON  VIEW THE MOON VIEW  I GOT FROM HERE
# Non-text characters: ["'"]
#
# Sample:  SHH IF  WE'RE VERY QUIET THE FISH MIGHT COME
# Non-text characters: ["'"]
#
# Sample:  WHO'S THEY
# Non-text characters: ["'"]
#
# Sample:  I KNOW  YOU DID YOU  THREW IT OUT OF THE WINDOW  INTO THE GRAND CANAL I DON'T THINK I'LL  EVER FORGIVE YOU FOR THAT
# Non-text characters: ["'", "'"]
#
# Sample:  THINGS THAT OUGHT TO MATTER DREADFULLY DON'T MATTER AT ALL WHEN ONE'S IS HAPPY DO THEY
# Non-text characters: ["'", "'"]
#
# Sample:   OH DARLING DON'T SAY THAT
# Non-text characters: ["'"]
#
# Sample:  WHAT DOES IT ALL MEAN THAT'S WHAT I ASK  THAT'S WHAT I ASK MYSELF IN MY CEASELESS QUEST FOR ULTIMATE TRUTH  GOOD GOD WHAT DOES IT ALL MEAN
# Non-text characters: ["'", "'"]
#
# Sample:  YOU MUSTN'T BE SERIOUS MY DEAR ONE THAT'S JUST WHAT THEY WANT
# Non-text characters: ["'", "'"]
#
# Sample:  NO NO IT ISN'T DEATH IS VERY LAUGHABLE  SUCH A  CUNNING LITTLE MYSTERY  ALL DONE WITH  MIRRORS
# Non-text characters: ["'"]
#
# Sample:   LET'S  BE SUPERFICIAL AND  PITY THE  POOR PHILOSOPHERS LET'S  BLOW OUR  TRUMPETS AND SQUEAKERS AND ENJOY THE  PARTY AS MUCH AS WE CAN  LIKE QUITE  IDIOTIC VERY SMALL  SCHOOL CHILDREN  LET'S  SAVOR THE DELIGHT OF THE MOMENT
# Non-text characters: ["'", "'", "'"]
#
# Sample:  THAT WAS A ROUSER WASN'T IT
# Non-text characters: ["'"]
#
# Sample:  I'LL NEVER FORGET HIS  FACE
# Non-text characters: ["'"]
#
# Sample:  IT'S  GOT  THAT  ALL ABOUT IT
# Non-text characters: ["'"]
#
# Sample:  BECAUSE IF HE'S NOT COMING BACK  I'LL  KILL MYSELF  I  MEAN  LAUGH  LAUGH AT ME BUT
# Non-text characters: ["'", "'"]
#
# Sample:   WHAT DO YOU MEAN  HE  LIVED NEXT DOOR TO THE GIRL ALL HIS LIFE  WHY WOULDN'T HE WANT TO SEE HER AGAIN
# Non-text characters: ["'"]
#
# Sample:   HOW DO YOU KNOW HE'S EVEN THINKING OF IT
# Non-text characters: ["'"]
#
# Sample:  YOU CAN'T READ HER MIND
# Non-text characters: ["'"]
#
# Sample:  HOW DO YOU KNOW WHY SHE'S WAITED
# Non-text characters: ["'"]
#
# Sample:  UM  HOW MAY  I HELP YOU YOU'RE  TRYING TO BOOK A SPECIFIC FLIGHT
# Non-text characters: ["'"]
#
# Sample:  OH  YEAH  ABSOLUTELY YOU KNOW  AND ESPECIALLY  BECAUSE YOU'VE BEEN WAITING SO LONG AND I KNOW THAT  UM YOU'VE BEEN HAVING A DIFFICULT TIME
# Non-text characters: ["'", "'"]
#
# Sample:  UM  LOTS OF PURCHASES  BUT WE'RE GONNA GO AHEAD AND GIVE THAT TO YOU ANYWAY  UH  JUST TO MAKE SURE THAT YOU'RE HAPPY WITH YOUR SERVICE  HERE
# Non-text characters: ["'", "'"]
#
# Sample:  ALL I'M GOING TO NEED IS YOUR  CREDIT CARD NUMBER BUT JUST GIVE ME ONE MOMENT SO
# Non-text characters: ["'"]
#
# Sample:  UM YOU'RE SCHEDULING A  FLIGHT AS WELL  AND YOU WOULD LIKE TO  UM  WE HAVE A HIGHLY DISCOUNTED HOTEL RATE THAT GOES ALONG WITH THAT  SO THAT  EVERYTHING IS  ALL IN ONE DEAL YOU'RE TAKEN CARE OF BY  THE TIME THAT YOU  GET THERE
# Non-text characters: ["'", "'"]
#
# Sample:  SO YOU WILL ABSOLUTELY  BE IN A  HIGH  RATED  GREAT HOTEL  AND WE CAN MAKE SURE THAT IT'S IN A  AREA OF TOWN THAT YOU LIKE  AS WELL
# Non-text characters: ["'"]
#
# Sample:   OKAY  GREAT FOUR SEATS I'LL BOOK YOU FOR FOUR SEATS
# Non-text characters: ["'"]
#
# Sample:  SO  IT'S A  FIVE HOUR FLIGHT BUT YOU'LL  ARRIVE  ONLY AT ELEVEN A CLOCK IN THE MORNING SO THAT DAY  YOU CAN HAVE  PLENTY OF TIME TO GET TO YOUR  HOTEL REST UP AND THEN STILL HAVE A NICE  AFTERNOON YOUR  FIRST AFTERNOON IN MAUI
# Non-text characters: ["'", "'"]
#
# Sample:  ABSOLUTELY THAT ACTUALLY  GOES IN ON THE SAME  PACKAGE  WITH  OUR HOTEL YOU JUST GIVE ME YOUR  ADDRESS WE'LL COME AND  PICK UP A TIME  THAT ALLOWS YOU TO GET TO YOUR  FLIGHT  WITH PLENTY OF TIME TO SPARE
# Non-text characters: ["'"]
#
# Sample:  YEAH  I  COMPLETELY UNDERSTAND IT'S A DIFFICULT PROCESS SOMETIMES AND WE WANT TO MAKE TRAVELING AS EASY AS POSSIBLE
# Non-text characters: ["'"]
#
# Sample:  YOU  YOU CAN DO THAT  YOU CAN DO THAT NOW I DON'T HAVE TO GET LIKE TRANSFERRED  THROUGH OR ANYTHING LIKE  THAT
# Non-text characters: ["'"]
#
# Sample:  BREATHING  THAT'S GOOD
# Non-text characters: ["'"]
#
# Sample:  ALL RIGHT I WANT TO MAKE SURE IT'S LIKE  A  NICE HOTEL I MEAN  MEAN  I'M GONNA BE PAYING A LOT OF MONEY FOR THIS SO I DON'T WANNA I DON'T WANNA  YOU  KNOW I DON'T WANNA TO BE  A WASTE OF TIME
# Non-text characters: ["'", "'", "'", "'", "'"]
#
# Sample:  WELL IT'S GONNA BE  FOUR OF  THEM
# Non-text characters: ["'"]
#
# Sample:   AND LIKE  THERE'S THERE'S  SHUTTLES OR SOMETHING THAT I CAN GET TO  THE HOTEL
# Non-text characters: ["'", "'"]
#
# Sample:  ALL RIGHT SO WE'RE CONFIRMED THEN OR DO YOU  ALL RIGHT
# Non-text characters: ["'"]
#
# Sample:   WELL IT'S TRUE
# Non-text characters: ["'"]
#
# Sample:  IT'S  BECOME A HABIT WITH YOU
# Non-text characters: ["'"]
#
# Sample:  DON'T  BE SO STUPID
# Non-text characters: ["'"]
#
# Sample:   IT'S A  WOMAN'S JOB TO ALLURE  THE MAN  WATCH  ME WON'T YOU A MINUTE
# Non-text characters: ["'", "'", "'"]
#
# Sample:  NO IT ISN'T
# Non-text characters: ["'"]
#
# Sample:   I DON'T CARE  I DON'T CARE DO YOU UNDERSTAND  I DON'T CARE  IF  THEY  BARK IF THEY  ROLL OVER ON THE  FLOOR  LIKE HOOPS
# Non-text characters: ["'", "'", "'"]
#
# Sample:   YOU ARE  QUITE INSUFFERABLE I SUPPOSE IT'S BECAUSE YOU'RE DRUNK
# Non-text characters: ["'", "'"]
#
# Sample:  YES  I  AM LET  GO OF ME  I  HATE  YOU AND  I  LOATH  YOU GOD  I  CAN'T BELIEVE  I  JUST  FINALLY  REALIZED HOW  YOU ARE  I  AM  NEVER  MARRY  YOU  NEVER  NEVER  NEVER NEVER  I  WOULD RATHER  DIE IN TORMENT
# Non-text characters: ["'"]
#
# Sample:  THAT'S A NICE POINT OF VIEW I MUST SAY
# Non-text characters: ["'"]
#
# Sample:   I'LL HAVE A LITTLE I THINK
# Non-text characters: ["'"]
#
# Sample:  YOU NEEDN'T BE SO  GRAND JUST BECAUSE YOU DON'T HAPPEN TO  WANT SOME YOURSELF AT THE MOMENT
# Non-text characters: ["'", "'"]
#
# Sample:  I IMAGINE THAT YOU LET HIM KISS YOU  QUITE  A  BIT MORE THEN  DIDN'T  YOU
# Non-text characters: ["'"]
#
# Sample:   I'M NOT IN THE LEAST BIT DRUNK
# Non-text characters: ["'"]
#
# Sample:  OKAY AS I MENTIONED BEFORE  I SAID I HAD  THREE VERY MINUTE LIQUOR GLASSES  THAT'S HARDLY ENOUGH TO GET A CHILD OF TWO DRUNK
# Non-text characters: ["'"]
#
# Sample:  YOU KNOW YOU'RE  A  VILE  ILL TEMPERED  WICKED LITTLE BEAST AND I  HOPE THAT I NEVER SEE YOU AGAIN AS LONG AS I LIVE
# Non-text characters: ["'"]
#
# Sample:  NO  YOU'RE NOT GOING OUT LIKE THIS  NO YOU'RE NOT
# Non-text characters: ["'", "'"]
#
# Sample:  I WOULDN'T  MARRY  YOU AGAIN IF YOU CAME BACK  CRAWLING TO ME ON YOUR HANDS AND KNEES BECAUSE YOU'RE  VILE  YOU'RE A MEAN EVIL MINDED LITTLE VAMPIRE AND I HOPE TO GOD I NEVER SET  EYES ON YOU AGAIN
# Non-text characters: ["'", "'", "'"]
#
# Sample:  IT'S NOT THE SAME THING IT'S NOT LIKE HAVING  YOU HERE
# Non-text characters: ["'", "'"]
#
# Sample:  I CAN'T  DO THIS
# Non-text characters: ["'"]
#
# Sample:  I'M  SICK OF  BEING  STRONG  FOR  US
# Non-text characters: ["'"]
#
# Sample:  A  WHOLE  YEAR  WE'RE  NOT TALKING ABOUT  LIKE A COUPLE MONTHS HERE I MEAN THIS IS A WHOLE  YEAR
# Non-text characters: ["'"]
#
# Sample:  AND THIS ISN'T THE FIRST TIME YOU KNOW I MEAN YOU ALWAYS  SENDING YOU OFF TO DIFFERENT PLACES AND
# Non-text characters: ["'"]
#
# Sample:  I DON'T KNOW IF THAT'S HOW I WANT TO LIVE MY  LIFE
# Non-text characters: ["'", "'"]
#
# Sample:   JOE I'M SERIOUS  I  DON'T WANT TO HAVE TO HAVE A LITTLE GIRL TO TELL  ASKING EVERY DAY WHERE'S DADDY WHERE'S DADDY AND HAVE TO TELL HER THAT  HE'S AWAY
# Non-text characters: ["'", "'", "'", "'", "'"]
#
# Sample:  FAR AWAY AND HE WON'T BE HERE
# Non-text characters: ["'"]
#
# Sample:   I'M DONE  I  CAN'T HONEY
# Non-text characters: ["'", "'"]
#
# Sample:  IT'S  OVER
# Non-text characters: ["'"]
#
# Sample:  HONEY I CAN'T DO IT ANYMORE
# Non-text characters: ["'"]
#
# Sample:  HONEY YOU'RE NOT GOING TO BE  BY YOURSELF
# Non-text characters: ["'"]
#
# Sample:  WE'LL HAVE INTERNET SET UP WE'LL GET WEB  CAMERAS AND EVERYTHING  MY WHOLE FAMILY'S HERE TOO
# Non-text characters: ["'", "'", "'"]
#
# Sample:  I DON'T KNOW WHAT  TO  DO
# Non-text characters: ["'"]
#
# Sample:  YOU KNOW I CAN'T  SAY  NO
# Non-text characters: ["'"]
#
# Sample:  WELL THAT'S THE KIND OF WORK I'M IN  HONEY
# Non-text characters: ["'", "'"]
#
# Sample:  IT'S JUST GOING TO BE  IT'S GOING TO GO FASTER THAN YOU  THINK
# Non-text characters: ["'", "'"]
#
# Sample:  HOW'S  IT  GOING  HOW  ARE  YOU  FEELING
# Non-text characters: ["'"]
#
# Sample:  I'M  SO  SORRY
# Non-text characters: ["'"]
#
# Sample:  YEAH  LIKE  I MEAN IF  YOU NEED ANYONE  TO  TALK  TO  OR ANYTHING I'M  HERE  FOR YOU  OKAY
# Non-text characters: ["'"]
#
# Sample:  WE'RE ALL HERE FOR  YOU
# Non-text characters: ["'"]
#
# Sample:  JUST  THINGS HAPPEN IN  LIFE AND YOU JUST THERE'S JUST NO EXPLANATION YOU KNOW  WE JUST  DON'T
# Non-text characters: ["'", "'"]
#
# Sample:  I'M  SO  SORRY
# Non-text characters: ["'"]
#
# Sample:  I WOULD'VE LOVED  TO
# Non-text characters: ["'"]
#
# Sample:  NOW  I  CAN'T
# Non-text characters: ["'"]
#
# Sample:   YOU KNOW A STUPID CASE OF  DRUNK DRIVING  IT'S JUST
# Non-text characters: ["'"]
#
# Sample:  AND JUST GOING TO THE FUNERAL IT'S
# Non-text characters: ["'"]
#
# Sample:  I MEAN I HAVEN'T EVEN TALKED TO HIM ON THE PHONE FOR THE PAST THREE MONTHS
# Non-text characters: ["'"]
#
# Sample:  HE'S  SUPPOSED TO BE MY BEST FRIEND
# Non-text characters: ["'"]
#
# Sample:  IT'S  SO  FUCKED UP
# Non-text characters: ["'"]
#
# Sample:  I  MEAN HE WAS  HE WANTED TO HELP PEOPLE IN POOR COUNTRIES THAT IS HIS GOAL HE DIDN'T CARE ABOUT THE MONEY  HE  JUST WANTED TO GO AND HELP PEOPLE
# Non-text characters: ["'"]
#
# Sample:   I  CAN'T  DO THAT
# Non-text characters: ["'"]
#
# Sample:  YOU SHOULD'VE MET  HIM
# Non-text characters: ["'"]
#
# Sample:   COULD HE HE'S ACTING JUST LIKE HE DID AFTER HE DIED YOU KNOW
# Non-text characters: ["'"]
#
# Sample:  IT'S THOSE GODDAMN NEWSPAPERS YOU KNOW  I  MEAN IT'S LIKE EVERY DAY THEY COME OUT WITH THIS NEW PERSON THAT COMES ALONG  AND THE NEXT ONE'S GOING TO BE LARRY
# Non-text characters: ["'", "'", "'"]
#
# Sample:   WELL  THAT'S ONLY YOUR BUSINESS CHRIS
# Non-text characters: ["'"]
#
# Sample:   YOU'RE A CONSIDERATE FELLA AND THERE'S NOTHING WRONG  IN THAT
# Non-text characters: ["'", "'"]
#
# Sample:   THERE'S NOTHING WRONG WITH IT
# Non-text characters: ["'"]
#
# Sample:   YOU'D LEAVE THAT  BUSINESS
# Non-text characters: ["'"]
#
# Sample:  I'M GOING TO
# Non-text characters: ["'"]
#
# Sample:   I DON'T KNOW YOU DO I
# Non-text characters: ["'"]
#
# Sample:   I DON'T KNOW  BUT AFTER IT CRACKED  HE WENT BACK IN  THE HOUSE AND HE CRIED IN THE KITCHEN
# Non-text characters: ["'"]
#
# Sample:   I DON'T KNOW
# Non-text characters: ["'"]
#
# Sample:  BUT I KNOW ONE THING MOM  WE'VE MADE A TERRIBLE MISTAKE WITH DAD
# Non-text characters: ["'"]
#
# Sample:   BEING DISHONEST  WITH HIM  THAT KIND OF THING ALWAYS PAYS OFF AND NOW IT'S PAYING OFF
# Non-text characters: ["'"]
#
# Sample:  SO  IT'S ALL RIGHT I'LL JUST GO AHEAD WITH IT
# Non-text characters: ["'", "'"]
#
# Sample:  SEE  THEN IT'S NOT JUST MY BUSINESS  GOD YOU HAVE
# Non-text characters: ["'"]
#
# Sample:  OH YOU INFURIATE ME SOMETIMES  YOU KNOW IT'S NOT JUST MY BUSINESS TOO IF DAD  THROWS A FIT
# Non-text characters: ["'"]
#
# Sample:   I DIDN'T ASK ANNIE YET
# Non-text characters: ["'"]
#
# Sample:  WELL THEN I GUESS IT'S  OVER THEN  BUT FROM HER LETTERS  I THINK  SHE'S FORGOTTEN  HIM
# Non-text characters: ["'", "'"]
#
# Sample:  I'LL FIND OUT  BUT THEN  AFTER IT'S ALL OVER WE'LL THRASH IT OUT WITH DAD  RIGHT
# Non-text characters: ["'", "'", "'"]
#
# Sample:   BUT IF I CAN'T HAVE THAT HERE THEN I'LL GET OUT
# Non-text characters: ["'", "'"]
#
# Sample:  I'LL GET OUT  I'LL MARRY HER SOMEWHERE ELSE  MAYBE NEW YORK
# Non-text characters: ["'", "'"]
#
# Sample:   NOW ANNIE'S IN THE MIDDLE OF ALL THAT
# Non-text characters: ["'"]
#
# Sample:  NO YOU DON'T  I'M A PRETTY TOUGH  GUY
# Non-text characters: ["'", "'"]
#
# Sample:   HOW'S IT GOING BABE
# Non-text characters: ["'"]
#
# Sample:  AND  UH  YEAH  UH  THEY'RE  GOING TO NEED  UM  MORE NURSES  ON  CALL  FOR  UH  TO GO OVERSEAS  TO HELP  OUT WITH THE WAR
# Non-text characters: ["'"]
#
# Sample:  IT'S  GOING  IT'S GOING TO BE  PROBABLY IN ABOUT  THREE WEEKS
# Non-text characters: ["'", "'"]
#
# Sample:  HONEY I'M GOING TO COME BACK IT'S  NOT LIKE  THAT
# Non-text characters: ["'", "'"]
#
# Sample:   BABE I'M SORRY  BUT  I DON'T WANT TO DO
# Non-text characters: ["'", "'"]
#
# Sample:  YOU KNOW AS MUCH  AS  AS  MUCH AS ME THAT I  I  WANT TO STAY HERE WITH  YOU AND AMY SO  BAD BUT I CAN'T
# Non-text characters: ["'"]
#
# Sample:  BUT SHE HAS YOU I MEAN THAT'S WHAT YOU'RE THERE  FOR  YOU'RE MY RIGHT HAND MAN
# Non-text characters: ["'", "'", "'"]
#
# Sample:  IT'S GOING TO BE OKAY
# Non-text characters: ["'"]
#
# Sample:  LOOK  I NEED YOU TO BE STRONG  FOR  ME  'CAUSE  I CAN'T BE THE ONLY ONE THAT'S STRONG RIGHT NOW  REALLY  I
# Non-text characters: ["'", "'", "'"]
#
# Sample:  WE'LL HAVE ALL THE MONEY  THAT WE EVER NEEDED
# Non-text characters: ["'"]
#
# Sample:  AND AND THEN I'LL  STOP  WORKING  AND I'LL STAY HOME WITH THE BABY
# Non-text characters: ["'", "'"]
#
# Sample:  IT'S  ALL I EVER KNEW HOW TO  DO I  CAN'T QUIT NOW
# Non-text characters: ["'", "'"]
#
# Sample:  WELL WE  WE TELL HER  MOMMY'S  GOING  ON  VA  ON A TRIP  FOR  FOR A WHILE
# Non-text characters: ["'"]
#
# Sample:  DON'T  DO THAT TO  ME
# Non-text characters: ["'"]
#
# Sample:  IT'S HARD ENOUGH ALREADY BRIAN I  CAN'T
# Non-text characters: ["'", "'"]
#
# Sample:  I DIDN'T EXPECT  THIS TO HAPPEN I  NEVER PLANNED FOR THIS  SOME THINGS YOU JUST DON'T  PLAN  FOR YOU  KNOW
# Non-text characters: ["'", "'"]
#
# Sample:  I'M  SORRY  BABE
# Non-text characters: ["'"]
#
# Sample:  I'M  SO SORRY
# Non-text characters: ["'"]
#
# Sample:   SHE'S DOING FINE SHE  JUST TOOK HER  FIRST STEPS TODAY ACTUALLY  I  VIDEOTAPED IT FOR YOU  SO YOU  CAN  WATCH IT
# Non-text characters: ["'"]
#
# Sample:  I CAN'T NO  I  CAN'T DO THIS ALONE
# Non-text characters: ["'", "'"]
#
# Sample:  YOU  CAN'T  LEAVE YOUR DAUGHTER ALONE LIKE  THIS
# Non-text characters: ["'"]
#
# Sample:  YOU  CAN'T POSTPONE IT
# Non-text characters: ["'"]
#
# Sample:  I DON'T KNOW IF I CAN HANDLE  YOU  GOING ANOTHER YEAR
# Non-text characters: ["'"]
#
# Sample:  I DON'T KNOW IF I  IF I COULD  TAKE  IT
# Non-text characters: ["'"]
#
# Sample:  I CAN'T  BE  THAT STRONG  A WHOLE  YEAR
# Non-text characters: ["'"]
#
# Sample:  IT DOESN'T LOOK VERY  GOOD
# Non-text characters: ["'"]
#
# Sample:  I DON'T WANT THE MONEY I WANT YOU  HERE
# Non-text characters: ["'"]
#
# Sample:  IF YOUR LIFE  IS GOING TO BE IN DANGER AND THIS FAMILY IS GOING TO BE IN DANGER WE DON'T NEED THE JOB  WE'LL FIND THE MONEY
# Non-text characters: ["'", "'"]
#
# Sample:  HOW ARE WE SUPPOSED TO TELL AMY  HOW'S SHE SUPPOSED TO UNDERSTAND THAT
# Non-text characters: ["'"]
#
# Sample:   HEY HOW'S IT GOING  I HAVEN'T  SEEN  YOU IN AWHILE
# Non-text characters: ["'", "'"]
#
# Sample:  WHAT'S  GOING ON JOE
# Non-text characters: ["'"]
#
# Sample:  YOU'RE GOING TO BE  HERE AND I'M GOING TO BE IN LA  SO WE CAN BE  TOGETHER NOW  I MEAN WE  CAN BE IN THE SAME  CITY
# Non-text characters: ["'", "'"]
#
# Sample:  YEAH HOPEFULLY IT WON'T BE LIKE HIGH  SCHOOL
# Non-text characters: ["'"]
#
# Sample:  THIS IS SO  GREAT YOU KNOW BECAUSE I GONE  FIT ON DOWNTOWN SO I'M GOING TO BE LIKE  RIGHT HERE I  THINK I'M GOING TO BE LIVING AT CITY LIGHTS  DOWNTOWN
# Non-text characters: ["'", "'"]
#
# Sample:   MAN I'M JUST SO HAPPY FOR YOU  I  JUST
# Non-text characters: ["'"]
#
# Sample:  WELL  I'M HAPPY FOR YOU  BUT I'M HAPPY  FOR ME CAUSE THAT MEANS YOU'RE GOING TO  STAY
# Non-text characters: ["'", "'", "'"]
#
# Sample:  NO IT'S LIKE  IT'S  HARDER THAN GETTING INTO HARVARD
# Non-text characters: ["'", "'"]
#
# Sample:  I HAVE SOME BAD NEWS I WAS LIKE  WHAT  SHE'S  LIKE NOT REALLY YOU GOT INTO U S C AND I WAS LIKE  I  WAS LIKE  OH MY GOD I WAS ABOUT TO TEAR MY OWN HAIR OUT
# Non-text characters: ["'"]
#
# Sample:  YEAH THIS IS  SO CRAZY  I MEAN I DIDN'T GET INTO  ANY OTHER SCHOOL BUT  I GOT INTO THE SCHOOL I WANTED
# Non-text characters: ["'"]
#
# Sample:  WE'RE  DOING WHAT WE WANT TO  DO THEN  FOUR YEARS LATER WE'RE GOING TO BE  WORKING  PROFESSIONALS MAKING  MONEY SIPPING MARTINIS  EVERY  DAY
# Non-text characters: ["'", "'"]
#
# Sample:   IT TOOK THEM  OH MAN IT TOOK THEM LIKE  I MEAN WHAT IT'S LIKE  APRIL NOW AND ANY LETTERS THAT COME IN APRIL ARE USUALLY THE REJECTION LETTERS SO I WAS JUST LIKE
# Non-text characters: ["'"]
#
# Sample:  AT THE END OF THE PERFORMANCE YOU KNOW  LIKE WE'RE ALL CLAPPING AND STUFF  AND ALL OF A SUDDEN I LOOK OVER AND
# Non-text characters: ["'"]
#
# Sample:  JOE'S GONE  WHERE DID HE GO YOU KNOW
# Non-text characters: ["'"]
#
# Sample:  AND I'M LIKE  OH  HE WENT TO THE THE  BATHROOM BUT HE DIDN'T TELL ME I DIDN'T EVEN NOTICE HIM LEAVING AND  ALL OF A SUDDEN I SWEAR TO GOD I'M SITTING THERE  AND
# Non-text characters: ["'", "'", "'", "'"]
#
# Sample:  GOES UP  THERE AND EVERYONE'S CLAPPING AND HE'S STANDING THERE  AND  THEY PUT A SPOTLIGHT ON HIM
# Non-text characters: ["'", "'"]
#
# Sample:  AND I'M LIKE  FREAKING OUT I'M LIKE  WHAT THE HELL'S GOING ON YOU KNOW I DON'T KNOW WHAT'S GOING ON AND SO  HE'S LIKE STANDING THERE AND THEN ALL OF A SUDDEN  THEY GIVE HIM A MICROPHONE
# Non-text characters: ["'", "'", "'", "'", "'", "'"]
#
# Sample:  HE ASKED ME TO MARRY HIM LIKE  ONSTAGE  I WAS LIKE  I  COULDN'T BELIEVE AND I HAD TO WALK UP  THERE AND I WAS  LIKE  I  THINK  I  TRIPPED OR SOMETHING
# Non-text characters: ["'"]
#
# Sample:  I  DON'T KNOW  IT JUST LIKE TOOK ME  TOOK ME BY  SURPRISE
# Non-text characters: ["'"]
#
# Sample:   OH  YEAH EVERYONE  YEAH  AND PEOPLE  FRIENDS OF OURS WERE IN THE AUDIENCE  I DIDN'T KNOW ABOUT LIKE  FAMILY MEMBERS
# Non-text characters: ["'"]
#
# Sample:   BUT  I  DON'T KNOW  I  IT'S SO WEIRD TO  THINK  I'M MARRYING  SOMEBODY 'CAUSE I  FEEL SO YOUNG  YOU KNOW
# Non-text characters: ["'", "'", "'", "'"]
#
# Sample:  YEAH  I'M  SO EXCITED LAUGHTER
# Non-text characters: ["'"]
#
# Sample:  THAT'S AWESOME  LAUGHTER  MARRIAGE
# Non-text characters: ["'"]
#
# Sample:  I DON'T UNDERSTAND WHY YOU'RE ALWAYS SAYING OH IT'S MINE IT'S MINE IT'S NOT LIKE IT'S JUST YOUR  FLASHLIGHT I MEAN HOW DO YOU THINK THAT MAKES ME  FEEL
# Non-text characters: ["'", "'", "'", "'", "'", "'"]
#
# Sample:   I DON'T KNOW I JUST  DON'T
# Non-text characters: ["'", "'"]
#
# Sample:   HEY WHAT TIME IS IT  THEY'RE SUPPOSED TO RUN AROUND  MIDNIGHT RIGHT  GOD  THIS IS GREAT ISN'T IT
# Non-text characters: ["'", "'"]
#
# Sample:  LOOK AT THE NIGHT  WE GOT COULDN'T BE BETTER
# Non-text characters: ["'"]
#
# Sample:   YOU KNOW ACTUALLY I WANTED TO GO A LITTLE FURTHER UP THE COAST TO GET AWAY FROM ALL THE  THE PEOPLE AND THE LIGHTS  AND UH  BUT I THOUGHT WE'D MISS IT  HEY HOW YOU DOING
# Non-text characters: ["'"]
#
# Sample:   OH  IS THAT  IS THAT  NOW IS THAT  JUST  FOAM UHH  I  CAN'T EVEN TELL
# Non-text characters: ["'"]
#
# Sample:  OH  THOUGH IF I CAN'T TELL IT PROBABLY ISN'T  THEM RIGHT IT PROBABLY WOULD BE UNMISTAKABLE WOULDN'T YOU THINK  HEY HOW YOU DOING
# Non-text characters: ["'", "'", "'"]
#
# Sample:   UH  YOU KNOW THE FLASHLIGHT  THE SILVER ONE THERE'S ONLY ONE  ISN'T THERE
# Non-text characters: ["'", "'"]
#
# Sample:  WE SHOULD HAVE BROUGHT OUR FLASHLIGHT  I CAN'T BELIEVE WE FORGOT TO  BRING IT
# Non-text characters: ["'"]
#
# Sample:  HEY DO THEY ALWAYS RUN DURING A FULL MOON  I CAN'T REMEMBER IF IT WAS FULL LAST YEAR  DO YOU  REMEMBER
# Non-text characters: ["'"]
#
# Sample:   WE SHOULD HAVE BROUGHT THE BLANKET  OH WHY DIDN'T WE BRING THE BLANKET OUR BLANKET
# Non-text characters: ["'"]
#
# Sample:  YOU KNOW WHAT WOULD BE GOOD RIGHT NOW  A SIX  PACK  AH  I  CAN'T BELIEVE I  FORGOT A SIX PACK A SIX PACK WOULD BE JUST THE TICKET RIGHT ABOUT NOW
# Non-text characters: ["'"]
#
# Sample:  I'M SO STUPID I'M LIKE A LITTLE KID  I IT'S AMAZING I GET OUT OF THE HOUSE WITH MY FLY ZIPPED  OH LAUGHTER
# Non-text characters: ["'", "'", "'"]
#
# Sample:  YEAH THAT'S MY POINT TOO
# Non-text characters: ["'"]
#
# Sample:   NO  NO NO NO THAT'S NOT MY POINT  MY  POINT IS THERE'S NO POINT  IN COMING DOWN HERE IF WE JUST TURN AROUND AND LEAVE
# Non-text characters: ["'", "'"]
#
# Sample:  I MEAN  DON'T YOU WANT TO SEE IT
# Non-text characters: ["'"]
#
# Sample:   I WOULDN'T MISS THIS FOR ANYTHING  I MEAN  THINK ABOUT THIS  OKAY I KNOW YOU'RE NOT INTERESTED BUT JUST THINK ABOUT THIS FOR A MINUTE
# Non-text characters: ["'", "'"]
#
# Sample:  AND THEY ALL  ALL AS ONE  TURNED AS ONE  AND FORMED THIS LINE AS  BIG AS THE CALIFORNIA COAST AND STARTED SWIMMING THIS WAY  SWIMMING  AS  IF THAT'S THE  ONLY  THING THAT  MATTERS
# Non-text characters: ["'"]
#
# Sample:  YOU KNOW THEY DIDN'T ASK IT A QUESTION  THEY DIDN'T  THEY DIDN'T TAKE A  VOTE  THEY DIDN'T  HAVE AN  INVITATION  OR A MAP  THEY JUST  STARTED SWIMMING  AS ONE
# Non-text characters: ["'", "'", "'", "'"]
#
# Sample:   ITS SINGLE MINDEDNESS  WITH ONE MIND  URGENCY  THAT'S PURE  URGE YOU KNOW THEY DON'T GIVE IT A NAME
# Non-text characters: ["'", "'"]
#
# Sample:  THEY DON'T  ASK IT A QUESTION THEY JUST  THEY JUST  THEY DON'T KNOW WHAT DRIVES THEM  THEY JUST TURN AS ONE  AND START THE SWIM THAT BRINGS THEM TO HERE
# Non-text characters: ["'", "'"]
#
# Sample:  WHERE WE STAND  FOR A MASSIVE CELEBRATION  OF SEX  AND  DEATH  OH  GOD I'M GIVING MYSELF  GOOSEBUMPS  LOOK I'M ALL ALL MY HAIRS ON MY ARMS IS  STICKING UP
# Non-text characters: ["'", "'"]
#
# Sample:   I MEAN IT WAS IT'S BOUND TO  COME OUT SOONER OR LATER
# Non-text characters: ["'"]
#
# Sample:   THAT'S  SERIOUS ENOUGH
# Non-text characters: ["'"]
#
# Sample:   I DON'T CARE THEN
# Non-text characters: ["'"]
#
# Sample:  I DIDN'T HIT YOU VERY HARD
# Non-text characters: ["'"]
#
# Sample:   SIR  YES IT'S IN MARYLAND  IT'S OKAY WELL I'M JUST LET ME CHECK  HERE
# Non-text characters: ["'", "'", "'"]
#
# Sample:  YOU'RE AT ME  AND I'M  GOING TO TRY TO HELP YOU  OUT SIR  BUT YOU JUST HAVE TO  COOPERATE WITH ME
# Non-text characters: ["'", "'"]
#
# Sample:  I'M SORRY SIR
# Non-text characters: ["'"]
#
# Sample:   I'M VERY SORRY BUT  LET'S CHECK ON THIS IMMEDIATELY THIS IS  DEFINITELY AN EMERGENCY  IT SEEMS
# Non-text characters: ["'", "'"]
#
# Sample:  YEAH  YOU DO THAT I'M COMING FROM BALTIMORE  YOU KNOW WHERE THAT IS
# Non-text characters: ["'"]
#
# Sample:   YOU DON'T KNOW WHERE WE'RE AT
# Non-text characters: ["'", "'"]
#
# Sample:   EIGHT  AND THEY'RE  ALL GONE
# Non-text characters: ["'"]
#
# Sample:  IT'S MY MOTHER'S  FUNERAL TOMORROW  AND THE  URN IS  IN THE SUITCASE
# Non-text characters: ["'", "'"]
#
# Sample:  OH  OH  THAT'S A GOOD DEDUCTION
# Non-text characters: ["'"]
#
# Sample:  SHERLOCK HOLMES GOD WHERE'S  MY  LUGGAGE
# Non-text characters: ["'"]
#
# Sample:  CALM DOWN  IT'S MY  MOTHER'S  FUNERAL  TOMORROW I'M THE ONE RESPONSIBLE  FOR THIS
# Non-text characters: ["'", "'", "'"]
#
# Sample:   DON'T YELL AT ME
# Non-text characters: ["'"]
#
# Sample:  YOU'RE THE MANAGER  YOU DON'T KNOW WHERE YOU WORK FOR  YOU DON'T KNOW WHERE YOU'RE AT AND YOU'RE THE MANAGER
# Non-text characters: ["'", "'", "'", "'", "'"]
#
# Sample:   IT'S  WEIRD  'CAUSE IT'S  LIKE YOU  EXPECTED IT  TO HAPPEN AND EVENTUALLY
# Non-text characters: ["'", "'", "'"]
#
# Sample:  IT'S  WEIRD I  THINK  I  FEEL SO ALONE  YOU KNOW  WHAT AM I GOING TO  DO NOW  NOW THAT HE'S  GONE
# Non-text characters: ["'", "'"]
#
# Sample:  HE'S  SO YOUNG  IT SEEMS SO
# Non-text characters: ["'"]
#
# Sample:  HIS  POOR PARENTS  YOU KNOW IT'S  THEIR ONLY SON
# Non-text characters: ["'"]
#
# Sample:  IT'S  WEIRD I  KIND OF  FEEL LIKE  PART OF ME IS  GONE NOW YOU KNOW
# Non-text characters: ["'"]
#
# Sample:   WE'RE ALL GOING TO MISS HIM
# Non-text characters: ["'"]
#
# Sample:  I DIDN'T KNOW HIM  TRICIA  BUT  UH  I HEARD  THAT HE  WAS A GREAT  MAN
# Non-text characters: ["'"]
#
# Sample:  HOW'S HIS PARENTS DOING
# Non-text characters: ["'"]
#
# Sample:  YOU GUYS WERE  PRETTY  CLOSE  WEREN'T  YOU
# Non-text characters: ["'"]
#
# Sample:  I DON'T KNOW
# Non-text characters: ["'"]
#
# Sample:  I  DON'T KNOW IF  BENNY WAS SMART  LIKE  THAT BUT
# Non-text characters: ["'"]
#
# Sample:   I'M SURE HE LOVED YOU  TOO  HE JUST DIDN'T KNOW IT
# Non-text characters: ["'", "'"]
#
# Sample:  NO I DIDN'T  YOU  MADE UP THE WHOLE THING IN YOUR  JEALOUS  IMAGINATION
# Non-text characters: ["'"]
#
# Sample:  WELL  IT DIDN'T HARM HIM IN  FACT IT PLEASURED HIM A LOT AND IT DIDN'T HURT ME
# Non-text characters: ["'", "'"]
#
# Sample:  I DON'T KNOW WHY YOU WANT IT YOU'VE ALREADY HAD TWO GLASSES
# Non-text characters: ["'", "'"]
#
# Sample:   I  DON'T SEE WHAT YOU HAVE TO GO  ON AND ON WITH THIS KIND OF THING
# Non-text characters: ["'"]
#
# Sample:  IT'S BECOME A HABIT WITH YOU
# Non-text characters: ["'"]
#
# Sample:  THAT'S  THE WOMAN'S JOB  TO LURE THE MAN  WATCH ME  A  MOMENT WON'T  YOU
# Non-text characters: ["'", "'", "'"]
#
# Sample:  ADDERS DON'T SNAP  THEY STING
# Non-text characters: ["'"]
#
# Sample:   YOU'RE  QUITE  INSUFFERABLE I EXPECT IT'S BECAUSE YOU'RE DRUNK
# Non-text characters: ["'", "'", "'"]
#
# Sample:  YOU'VE ALWAYS HAD A  WEAK HEAD
# Non-text characters: ["'"]
#
# Sample:  I HATE YOU  LISTEN  I'M SICK  AND TIRED OF  LISTENING TO YOU  YOU  SADISTIC  BULLY
# Non-text characters: ["'"]
#
# Sample:  OH  YES  I  AM  YES  I  AM AND YOU CAN'T STOP  ME
# Non-text characters: ["'"]
#
# Sample:  LISTEN  YOU'RE A  CRUEL  FIEND  AND I HATE  LOATHE  YOU  THANK  GOD  FINALLY  FINALLY  THANK GOD I'VE  REALIZED JUST  HOW  HORRIBLE  YOU  ARE  AND MARRY  YOU  MARRY YOU NEVER  I  WILL NEVER  MARRY  YOU  I  WILL  DIE DIE  IN TORMENT
# Non-text characters: ["'", "'"]
#
# Sample:  OH  THAT'S A NICE POINT OF VIEW I MUST SAY
# Non-text characters: ["'"]
#
# Sample:   I'LL HAVE A LITTLE I THINK
# Non-text characters: ["'"]
#
# Sample:  YOU NEEDN'T BE SO GRAND  JUST BECAUSE YOU DON'T HAPPEN TO  WANT ANY  YOURSELF AT  THE  MOMENT
# Non-text characters: ["'", "'"]
#
# Sample:   ACTUALLY THAT'S PERFECTLY TRUE
# Non-text characters: ["'"]
#
# Sample:  I'M NOT IN THE LEAST BIT DRUNK
# Non-text characters: ["'"]
#
# Sample:  OKAY LIKE I MENTIONED BEFORE  I HAD  THREE VERY SMALL MINUTE  LIQUOR GLASSES  OF BRANDY  THAT'S NOT EVEN ENOUGH TO GET A CHILD OF TWO  DRUNK
# Non-text characters: ["'"]
#
# Sample:  NO  I'LL DO NO SUCH THING
# Non-text characters: ["'"]
#
# Sample:  COME ON TURN IT  OFF  IT'S DRIVING ME MAD
# Non-text characters: ["'"]
#
# Sample:  YOU KNOW WHAT  YOU'RE  A  VILE  LITTLE  EVIL MINDED  LITTLE WICKED BEAST  AND I NEVER WANT TO SEE YOU AGAIN
# Non-text characters: ["'"]
#
# Sample:  YOU'RE NOT GOING NOWHERE  NO YOU'RE NOT
# Non-text characters: ["'", "'"]
#
# Sample:  SHUT  UP  SHUT  UP  I  WOULD I WOULD NEVER  MARRY  YOU AGAIN IF  YOU CAME CRAWLING BACK TO ME ON YOUR HANDS AND KNEES BECAUSE YOU'RE AN  EVIL  MINDED LITTLE  VAMPIRE  AND I HOPE TO GOD I NEVER SEE YOU AGAIN
# Non-text characters: ["'"]
#
# Sample:  YOU'RE THE ONLY ONE I KNOW THAT STILL LOVES HIS  PARENTS
# Non-text characters: ["'"]
#
# Sample:  NO IT'S  ALL RIGHT THERE'S NOTHING WRONG IN THAT YOU KNOW
# Non-text characters: ["'", "'"]
#
# Sample:  IT'S REALLY LOVELY HERE  THE AIR IS SWEET
# Non-text characters: ["'"]
#
# Sample:  NO I'M  NOT SORRY IT'S
# Non-text characters: ["'", "'"]
#
# Sample:  WELL YOU'VE BEEN EMBARRASSED EVER SINCE I CAME
# Non-text characters: ["'"]
#
# Sample:   WELL  I GUESS THAT'S  WHY I  CAME
# Non-text characters: ["'"]
#
# Sample:   I'VE BEEN  READY FOR A  LONG LONG TIME
# Non-text characters: ["'"]
#
# Sample:  I  DON'T  KNOW IF  I EVER CAN  FORGIVE YOU  FOR THAT  WHY'D  YOU WAIT SO LONG  I  SAT IN MY  ROOM WONDERING IF  I WAS CRAZY FOR THINKING ABOUT YOU
# Non-text characters: ["'", "'"]
#
# Sample:   LIKE  LARRY'S BROTHER  DO IT LIKE  YOU  CHRIS
# Non-text characters: ["'"]
#
# Sample:  WELL  THEN  TELL ME WHAT'S WRONG I MEAN EVEN IN YOUR LETTERS THERE'S SOMETHING ASHAMED
# Non-text characters: ["'", "'"]
#
# Sample:  BUT CHRIS IT WOULDN'T WORK LIKE  THIS
# Non-text characters: ["'"]
#
# Sample:  BECAUSE YOU  CAN'T FEEL  THAT WAY NEVER AGAIN CHRIS  YOU HEAR  ME NEVER  I  MEAN  THE MONEY AND ME TOO
# Non-text characters: ["'"]
#
# Sample:  YEAH  I KNOW  IT WENT OUT OF STYLE  DIDN'T IT
# Non-text characters: ["'"]
#
# Sample:  YOU'RE NOT SORRY YOU CAME
# Non-text characters: ["'"]
#
# Sample:  OH LOOK  UM  WELL THE THING IS I WAS PLANNING ON  PLANNING ON SORT OF SNEAKING UP ON YOU OVER A WEEK OR SO  AND  THEY  THEY TAKE IT FOR GRANTED WE'RE ALL SET
# Non-text characters: ["'"]
#
# Sample:  I I  GUESS THAT'S  WHY I ASKED YOU TO COME
# Non-text characters: ["'"]
#
# Sample:   I  I LOVE YOU  I  HAVE  NO IMAGINATION THAT'S ALL I KNOW HOW TO TELL IT
# Non-text characters: ["'"]
#
# Sample:  I'M EMBARRASSING YOU  I DIDN'T WANT TO TELL YOU IT HERE  I WANTED TO GO SOMEWHERE THAT WOULD BE  BRAND NEW  TO  EACH OTHER  IT FEELS WRONG HERE DON'T YOU  THIS YARD AND  THIS CHAIR
# Non-text characters: ["'", "'", "'"]
#
# Sample:   I DON'T WANT TO WIN YOU FROM ANYBODY  I WANT YOU TO BE READY FOR ME
# Non-text characters: ["'"]
#
# Sample:  WHY DIDN'T YOU LET ME KNOW
# Non-text characters: ["'"]
#
# Sample:   WE'RE GOING TO LIVE  NOW  I'M GOING TO MAKE YOU SO HAPPY
# Non-text characters: ["'", "'"]
#
# Sample:   LET'S DRIVE SOMEWHERE  I WANT TO BE ALONE WITH YOU
# Non-text characters: ["'"]
#
# Sample:  YEAH  I  GUESS THERE IS  I  GUESS I WAS  BUT  UH  IT'S  GOING FROM ME NOW
# Non-text characters: ["'"]
#
# Sample:  I DON'T KNOW WHERE TO START
# Non-text characters: ["'"]
#
# Sample:  IT  TAKES A  LITTLE WHILE TO TOSS  THAT OFF  BECAUSE THEY WEREN'T JUST MEN
# Non-text characters: ["'"]
#
# Sample:  I  MEAN THAT'S  THAT'S ONLY A LITTLE  THING  BUT  THAT'S THE KIND OF GUYS I HAD  THEY DIDN'T JUST DIE  THEY KILLED THEMSELVES FOR EACH OTHER  AND I MEAN THAT EXACTLY  A  LITTLE MORE SELFISH AND THEY'D STILL BE HERE TODAY
# Non-text characters: ["'", "'", "'", "'", "'"]
#
# Sample:  OTHERWISE WHAT YOU HAVE HERE IS LOOT  AND THERE'S BLOOD ON  IT
# Non-text characters: ["'"]
#
# Sample:  AND I DIDN'T WANT TO TAKE ANY OF IT
# Non-text characters: ["'"]
#
# Sample:  ANNIE I'M GOING TO MAKE A FORTUNE FOR YOU
# Non-text characters: ["'"]
#
# Sample:   WELL  SHE'S BEEN AWAY  FOR THREE AND A HALF  YEARS IN NEW YORK AND SUDDENLY  SHE JUST  SHOWS UP
# Non-text characters: ["'"]
#
# Sample:  NO  SHE'S NOT HIS GIRL JOE AND SHE KNOWS THAT
# Non-text characters: ["'"]
#
# Sample:  IT'S LIKE  I KNOW AS LONG AS SHE'S WAITING  I'M RIGHT AGAIN
# Non-text characters: ["'", "'", "'"]
#
# Sample:  I  CAN'T HELP IT
# Non-text characters: ["'"]
#
# Sample:   HOW DO YOU KNOW WHY SHE'S WAITED  HMMM
# Non-text characters: ["'"]
#
# Sample:  LOOK AT YOU YOU'RE SHAKING
# Non-text characters: ["'"]
#
# Sample:  WHAT DO I GOT TO HIDE  HUH  WHAT THE HELL'S THE MATTER WITH YOU KATE
# Non-text characters: ["'"]
#
# Sample:   SHE'S BEEN IN NEW YORK FOR THREE AND A HALF  YEARS  SHE DON'T JUST SUDDENLY COME AND
# Non-text characters: ["'", "'"]
#
# Sample:  YOU DON'T TRAVEL SEVEN HUNDRED MILES JUST TO SEE
# Non-text characters: ["'"]
#
# Sample:   IT'S GOT THAT ABOUT IT
# Non-text characters: ["'"]
#
# Sample:  SHE'S NOT  LARRY'S  GIRL  SHE KNOWS THAT
# Non-text characters: ["'", "'"]
#
# Sample:  SHE'S  FAITHFUL AS A  ROCK  DON'T  YOU  KNOW  IN MY WORST MOMENTS  I CAN THINK OF HER
# Non-text characters: ["'", "'"]
#
# Sample:  DON'T DON'T LAUGH AT  ME DON'T LAUGH  AT ME
# Non-text characters: ["'", "'", "'"]
#
# Sample:   NO  YOU'VE GOT TO BELIEVE
# Non-text characters: ["'"]
#
# Sample:  I  CAN'T HELP  IT
# Non-text characters: ["'"]
#
# Sample:   HOW DO YOU KNOW HE'S EVEN THINKING ABOUT  IT
# Non-text characters: ["'"]
#
# Sample:  YOU CAN'T READ HER MIND
# Non-text characters: ["'"]
#
# Sample:  HOW DO YOU KNOW WHY SHE'S WAITED
# Non-text characters: ["'"]
#
# Sample:   LOOK IT'S A NICE DAY  WHAT ARE WE ARGUING FOR
# Non-text characters: ["'"]
#
# Sample:  LOOK  AT YOU YOU'RE SHAKING
# Non-text characters: ["'"]
#
# Sample:  HUH WHAT THE HELL'S THE MATTER WITH YOU KATE
# Non-text characters: ["'"]
#
# Sample:   WELL  OKAY  WELL THAT'S
# Non-text characters: ["'"]
#
# Sample:   WELL WHAT'D YOU MAJOR IN
# Non-text characters: ["'"]
#
# Sample:  WELL  I'M MOVING UP  I  MEAN IT COULD BE
# Non-text characters: ["'"]
#
# Sample:   WELL  IF YOU NEED SOMETHING I MEAN YOU'RE  JUST GOING  TO  CAN GET A TEMPORARY THING  RIGHT NOW AND THEN LOOK FOR SOMETHING
# Non-text characters: ["'"]
#
# Sample:  IT'S GOING TO GET BETTER I PROMISE YOU YOU JUST GOT TO HANG IN THERE  EVERYONE I MEAN  YOU KNOW
# Non-text characters: ["'"]
#
# Sample:  I'M JUST SO TIRED ALL THE TIME
# Non-text characters: ["'"]
#
# Sample:  I'M SMARTER THAN HALF THE PEOPLE I WORK FOR
# Non-text characters: ["'"]
#
# Sample:  YEAH  IT'S ALRIGHT  BUT
# Non-text characters: ["'"]
#
# Sample:  MAYBE I'LL JUST KILL MYSELF
# Non-text characters: ["'"]
#
# Sample:  LIKE WOW YOU'RE REALLY SMART WE'RE GOING TO GIVE YOU AN EXTRA  GARBAGE
# Non-text characters: ["'", "'"]
#
# Sample:  I  JUST  I SEE ALL  THESE OTHER  PEOPLE GETTING  COMMERCIALS AND WORK AND IT'S  LIKE  I'M NOT GETTING ANYTHING
# Non-text characters: ["'", "'"]
#
# Sample:  IT'S NOT FUNNY  I  JUST DON'T KNOW WHAT I'M GOING TO DO
# Non-text characters: ["'", "'", "'"]
#
# Sample:  NO  DON'T THINK  LIKE  THAT
# Non-text characters: ["'"]
#
# Sample:  RUSSEL CROWE WASN'T  FORTY UNTIL HE GOT HIS BIG  STUFF
# Non-text characters: ["'"]
#
# Sample:  WE'RE JUST POOLING OUR FUNDS TOGETHER
# Non-text characters: ["'"]
#
# Sample:  YOU DON'T  OWE  ME ANYTHING
# Non-text characters: ["'"]
#
# Sample:  YOU ARE YOU'RE GOING TO CLASS YOU'RE LEARNING YOU'RE GETTING BETTER  WHEN YOU  FINALLY GET THAT ROLE YOU'RE GOING TO BE PREPARED
# Non-text characters: ["'", "'", "'", "'"]
#
# Sample:  OH  MY GOD  ANNA YOU'RE STILL YOUNG  DON'T EVEN THINK ABOUT  THAT
# Non-text characters: ["'", "'"]
#
# Sample:  YOU'RE  ONLY TWENTY FIVE  OKAY SOME PEOPLE DON'T START UNTIL THEY'RE  THIRTY  FIVE
# Non-text characters: ["'", "'", "'"]
#
# Sample:  WHAT  WOULD YOU  DO  WHAT WOULD YOU DO  IF  YOU DIDN'T  YOU  CAN GO  TO LAW SCHOOL
# Non-text characters: ["'"]
#
# Sample:  SEE SO YOU CAN'T JUST QUIT  NOW
# Non-text characters: ["'"]
#
# Sample:   HOW'S THE JOB  STILL WAITING TABLES AT  DENNY'S
# Non-text characters: ["'", "'"]
#
# Sample:  MAYBE YOU COULD START TEACHING  I DON'T KNOW
# Non-text characters: ["'"]
#
# Sample:  GO BACK TO SCHOOL  YOU KNOW  ANOTHER THREE MORE YEARS GET YOUR MASTER'S
# Non-text characters: ["'"]
#
# Sample:  CLOSE TO  THIRTY  OOF  IT'S  GOING  TO  BE  TOUGH
# Non-text characters: ["'"]
#
# Sample:  IT'S RIDICULOUS
# Non-text characters: ["'"]
#
# Sample:   IT'S  PR I  MEAN SOMEBODY SOLD YOU A GOOD BILL  ABOUT THIS WONDERFUL EVENT THAT GOING TO HAPPEN ON THE BEACH
# Non-text characters: ["'"]
#
# Sample:   YEAH EVERYONE ELSE WAS SOLD THE  SAME THING  I MEAN LOOK  IT KEEPS US EXCITED IT KEEPS US  COMING  BACK  FOR MORE AND YOU KNOW KEEPS US THINKING  LIFE'S GOING TO START ANY MINUTE NOW
# Non-text characters: ["'"]
#
# Sample:   LOOK I'M  SORRY BUT IT'S STILL JUST  FISH TO  ME
# Non-text characters: ["'", "'"]
#
# Sample:  OKAY  TWICE IS AS MANY TIMES AS WE'VE  TRIED AND THAT'S  EVER
# Non-text characters: ["'", "'"]
#
# Sample:   AUGIE GOD DAMMIT DON'T ASK ME THAT YOU ALWAYS ASK ME THAT I HATE IT WHEN YOU ASK ME THAT  IT'S INSULTING
# Non-text characters: ["'", "'"]
#
# Sample:  LISTEN  I'VE WAITING  MY  ENTIRE  LIFE ON THIS  BEACH JUST  STANDING THERE WAITING FOR THIS  FISH TO SHOW UP AND THESE FISH NEVER  SHOW UP
# Non-text characters: ["'"]
#
# Sample:  NO WE  WON'T I MEAN  GOD THIS ISN'T ABOUT THE  FISH  AUGIE
# Non-text characters: ["'", "'"]
#
# Sample:   I'D RATHER NOT REMEMBER SOMETHING
# Non-text characters: ["'"]
#
# Sample:   I  WANT  THINGS TO TURN OUT THE WAY THAT THEY'RE SUPPOSED TO BE
# Non-text characters: ["'"]
#
# Sample:   CAUSE EVERYTHING  ISN'T  ANYTHING LIKE  I  THOUGHT IT WOULD BE
# Non-text characters: ["'"]
#
# Sample:   THIS IS JUST THIS YOU KNOW I MEAN IT'S  A  LOT AND EVERYTHING BUT IT  ISN'T SOMEWHERE ELSE DO  YOU KNOW WHAT  I'M  TRYING  TO SAY
# Non-text characters: ["'", "'", "'"]
#
# Sample:  I CAN'T HELP  THINKING ABOUT  BEING SOMEWHERE ELSE
# Non-text characters: ["'"]
#
# Sample:   I DIDN'T SAY  THAT
# Non-text characters: ["'"]
#
# Sample:  AUGIE  WHATEVER I'M DOING  I'D  RATHER  BE DOING WITH YOU
# Non-text characters: ["'", "'"]
#
# Sample:  IF ANYBODY WANTS  TO  BE WITH ANYBODY ELSE IT'S  PROBABLY YOU  PROBABLY SOMEBODY WHO ENJOYS HERSELF A LITTLE  MORE AND IS  NOT SO  HARD
# Non-text characters: ["'"]
#
# Sample:  YEAH I NOTICED THAT IT'S REAL  PRETTY ON THE WATER
# Non-text characters: ["'"]
#
# Sample:   NO I'M  BEGINNING TO THINK YOU MIGHT BE RIGHT
# Non-text characters: ["'"]
#
# Sample:  WELL  WE'RE GOING TO SEE IT
# Non-text characters: ["'"]
#
# Sample:   LET'S SEE I  TOOK A SHOWER  YOU WERE WATCHING THE NEWS YOU SAID HEY  HEY THE GRUNIONS ARE RUNNING TONIGHT AND I SAID  GREAT  LET'S GO  I  FEEL LUCKY  TONIGHT
# Non-text characters: ["'", "'"]
#
# Sample:  WAIT A MINUTE  I'VE GOT IT
# Non-text characters: ["'"]
#
# Sample:  AND  YOU SAID LET'S GET SOME CHAMPAGNE AND I SAID  TIME'S A WASTING OR SOMETHING LIKE  THAT
# Non-text characters: ["'", "'"]
#
# Sample:  YOU  WANT THIS TO BE LIKE  THE OTHER TIME RIGHT THAT'S  IT RIGHT
# Non-text characters: ["'"]
#
# Sample:   DO YOU THINK  THAT THIS IS WHAT I HAD IN MIND  THAT FOUR YEARS DOWN THE LINE  THAT WE'D GET MARRIED AND COME TO THE BEACH AND  ARGUE WITH EACH OTHER  OVER FISH  NO
# Non-text characters: ["'"]
#
# Sample:   I WAS JUST LIKE YOU  I THOUGHT IT WAS GOING TO BE ALL  PEACHES AND ROSES AND EVERYTHING GREAT AND  THE SAND IN OUR TOES AND THE WIND IN OUR HAIR AND THE  FISH WILL ALWAYS COME  AND THE BILLS WILL PAY THEMSELVES AND WE'D HAVE  THREE  BIG FAT  ROSY  KIDS
# Non-text characters: ["'"]
#
# Sample:  I KNOW  BUT I KNOW I DON'T MAKE YOU HAPPY
# Non-text characters: ["'"]
#
# Sample:   SHH IF  WE'RE VERY QUIET THE  FISH  MIGHT  COME
# Non-text characters: ["'"]
#
# Sample:  I'M JUST NOT
# Non-text characters: ["'"]
#
# Sample:   HEY WHAT TIME IS IT  THIS POKES AROUND  MIDNIGHT RIGHT  GOD THIS IS GREAT ISN'T IT
# Non-text characters: ["'"]
#
# Sample:   LOOK AT THE NIGHT WE GOT  I WOULDN'T TRADE THIS FOR ANYTHING
# Non-text characters: ["'"]
#
# Sample:   YOU KNOW ACTUALLY I WANTED TO GO A LITTLE FURTHER UP THE COAST AND  GET AWAY FROM ALL THE LIGHTS AND PEOPLE  BUT I WAS AFRAID  YOU'D MISS IT  HOW ARE YOU DOING
# Non-text characters: ["'"]
#
# Sample:   IS THAT  IS THAT  NAH IS THAT  JUST PAUL  I CAN'T EVEN TELL
# Non-text characters: ["'"]
#
# Sample:  BUT IF I CAN'T TELL IT PROBABLY ISN'T THEM ISN'T  IT  PROBABLY WOULD BE  UNMISTAKABLE WOULDN'T YOU THINK HOW ARE YOU DOING
# Non-text characters: ["'", "'", "'", "'"]
#
# Sample:   OH YOU KNOW WHAT I FORGOT I  FORGOT  MY  FLASHLIGHT HOW COULD I BE SO STUPID I SHOULD'VE BROUGHT MY FLASHLIGHT
# Non-text characters: ["'"]
#
# Sample:  I'M SO STUPID I SHOULD'VE BROUGHT A SIX PACK  GOD I'M LIKE A LITTLE KID IT'S AMAZING I GET OUT OF THE HOUSE WITH MY FLY  ZIPPED  UP  OH LAUGHTER
# Non-text characters: ["'", "'", "'", "'"]
#
# Sample:  HONEY  THIS IS A NATURAL PHENOMENON IT ONLY HAPPENS ONCE A  YEAR  I MEAN THINK ABOUT THE  PEOPLE IN KANSAS  THEY WOULD HAVE TO GET HOTEL RESERVATIONS AND PLANE TICKETS TO COME AND SEE THIS  WE'RE ONLY FORTY MINUTES AWAY  THIS IS TOO GOOD TO PASS UP
# Non-text characters: ["'"]
#
# Sample:   WELL  THIS IS  LIKE  THE HIGHLIGHT  THE ONE NIGHT OF THEIR LIVES  AND THAT FLOPPING AROUND THAT'S LAYING EGGS OR  SPAWNING OR  MATING OR  WHATEVER  YOU  CALL  IT
# Non-text characters: ["'"]
#
# Sample:  BUT THIS  IS THE BIG NIGHT FOR  THESE  GUYS  THEIR LAST  LIFE'S LAST  ORGY
# Non-text characters: ["'"]
#
# Sample:  OKAY  BUT IT'S FISH THAT  DO SOMETHING THAT NO OTHER FISH DO  LIKE  THE SWALLOWS IN CAPISTRANO  OR THE LEMMINGS THAT  THROW THEMSELVES OFF THE CLIFFS THERE'S  MAGIC  HERE AND SOME  MYSTERY AND A LITTLE BIT OF UNEXPLAINABLE
# Non-text characters: ["'", "'"]
#
# Sample:   YOU KNOW THIS IS GREAT ISN'T IT  YOU KNOW  I WOULDN'T TRADE THIS FOR ANYTHING
# Non-text characters: ["'", "'"]
#
# Sample:  I MEAN  THINK ABOUT THIS  I KNOW YOU'RE NOT INTERESTED BUT JUST THINK ABOUT THIS FOR A MINUTE
# Non-text characters: ["'"]
#
# Sample:   SOMEWHERE OUT THERE  THERE'S THIS HUGE SILVER MASS OF FISH  HEADING THIS  WAY  THEY DON'T WHY  WE DON'T KNOW WHY THEY JUST SOME  LITTLE INSTINCTUAL FIRE  CRACKER WENT OFF IN THEIR BODIES
# Non-text characters: ["'", "'", "'"]
#
# Sample:  LIKE AND  THEY ALL JUST TURNED AT  ONCE  AND FORMED  A LINE AS LONG AS THE CALIFORNIA COAST AND STARTED SWIMMING THIS WAY  THEY DIDN'T  YOU KNOW  THEY DIDN'T MAKE A DECISION  THEY DIDN'T  YOU KNOW  HAVE  BOATS  OR ANYTHING NO ONE SENT THEM AN INVITATION OR A MAP THEY JUST STARTED SWIMMING  AS IF THAT'S THE  ONLY THING THAT MATTERS
# Non-text characters: ["'", "'", "'", "'"]
#
# Sample:  IT'S  SINGLE MINDEDNESS WITH  NO MIND  IT'S  URGENCY  THAT'S PURE  URGE  AND THEY DON'T  THEY DON'T  ASK IT A QUESTION  THEY DON'T  GIVE IT A NAME  THEY JUST SWIM
# Non-text characters: ["'", "'", "'", "'", "'", "'"]
#
# Sample:   OH  I'M  GIVING MYSELF  GOOSE BUMPS LOOK ALL MY HAIRS ARE  STANDING UP
# Non-text characters: ["'"]
#
# Sample:   WHERE  I DON'T  KNOW THE LOST AND FOUND WHAT DO YOU  MEAN  LOST AND FOUND
# Non-text characters: ["'"]
#
# Sample:   WAIT SIR  YOU'RE  YOU'RE COMPLETELY NOT  WHAT DO YOU MEAN STOLE IT HOW CAN THEY JUST STEAL IT FROM AN AIRPLANE IT WAS UP  IN THE AIR
# Non-text characters: ["'", "'"]
#
# Sample:  WHAT  THERE THERE'S  HUNDREDS OF  THOUSANDS OF  DOLLARS WORTH OF STUFF IN THERE
# Non-text characters: ["'"]
#
# Sample:  NO THEY  SAID  I  COULDN'T LOCK IT
# Non-text characters: ["'"]
#
# Sample:  GIVE ME I'M GOING TO TALK TO YOUR SUPERVISOR  GIVE ME YOUR SUPERVISOR  I  WANT TO TALK TO YOUR SUPERVISOR RIGHT NOW
# Non-text characters: ["'"]
#
# Sample:   OH NOT WE DIDN'T LOSE IT  MAYBE  THE AIRPORT LOST IT  MAYBE SOMEONE STOLE  IT
# Non-text characters: ["'"]
#
# Sample:  AND WHEN YOU SIGN YOUR TICKET  WE COULD REPLACE ABOUT  FIFTEEN PERCENT  OF WHAT'S IN THE BAG
# Non-text characters: ["'"]
#
# Sample:   I THINK THAT'S KIND OF STUPID THAT  YOU PUT A HUNDRED  THOUSANDS OF DOLLARS IN THE BAG
# Non-text characters: ["'"]
#
# Sample:  OKAY LET ME GET HIM  OH GUESS WHO  THE SUPERVISOR IS IT'S ME
# Non-text characters: ["'"]
#
# Sample:  NO  I  DID  NOT DROP MY  PHONE  IN  WATER I'M NOT  FIVE YEARS  OLD AND  JUST DROPPED MY  PHONE  ANYWHERE I  SEE IT  OKAY THIS IS  MY  BUSINESS
# Non-text characters: ["'"]
#
# Sample:   ALRIGHT  WELL  I  GUESS  I  GUESS  THAT'S  OKAY BUT
# Non-text characters: ["'"]
#
# Sample:  I'M  SORRY  MA'AM  WHAT'S THE NATURE OF YOUR PROBLEM  BUT FIRST CAN I GET YOU TO  TELL ME YOUR  FIRST AND  LAST NAME
# Non-text characters: ["'", "'", "'"]
#
# Sample:   I  KNOW I  JUST NEED TO VERIFY  EVERY  TIME  I'M  SORRY
# Non-text characters: ["'"]
#
# Sample:  ALRIGHT MS BROWN WHAT'S THE NATURE OF YOUR  PROBLEM
# Non-text characters: ["'"]
#
# Sample:   OH I'M  SORRY  UM  DID YOU  DROP IT IN WATER
# Non-text characters: ["'"]
#
# Sample:  UM  WELL IT'S  PROBABLY  EASY  CAN YOU  ANY  MORE SYMPTOMS EITHER YOU'RE NOT  RECEIVING  CALLS  OK  YOU'RE  NOT RECEIVING CALLS  NOT  GETTING  CALLS
# Non-text characters: ["'", "'", "'"]
#
# Sample:   WELL  UM  OKAY  YOUR SIM  CARD IS IN  DIDN'T  FALL OUT
# Non-text characters: ["'"]
#
# Sample:   OKAY  HOW ABOUT THIS  WE'LL  SEND YOU  A  BRAND NEW  CAMERA PHONE  WITH  PALM  PILOT  AND
# Non-text characters: ["'"]
#
# Sample:  SO  WE'LL  SEND IT  AND  WE'LL  GIVE YOU HOW ABOUT A FREE YEAR'S SERVICE
# Non-text characters: ["'", "'", "'"]
#
# Sample:  TELL THEM THAT  YOU  CAN GO IN  GET A BRAND NEW PHONE  THEY'LL HOOK YOU UP  WITH SERVICE  EVEN GIVE YOU A FREE  THREE  MONTHS
# Non-text characters: ["'"]
#
# Sample:  OKAY  THEY  CAN  FIGURE OUT PINK  FOR YOU  SO GO IN THERE AND JUST TELL THEM THAT AND THEY'LL HOOK  YOU UP  WITH OTHER GOODIES STUFF LIKE THAT  FREE SERVICE  NO CONTRACT  NO NOTHING JUST  FOR  BEING A GOOD  CUSTOMER
# Non-text characters: ["'"]
#
# Sample:   OH LIKE  THAT ONE MOVIE WHAT'S THAT ONE MOVIE I JUST SAW  NO  WHERE  SHE  LIKE SWALLOWS THE
# Non-text characters: ["'"]
#
# Sample:   OH I DON'T REMEMBER  EVERYBODY  SAYS  I LOVE YOU  WITH  DREW BARRYMORE NO  YOU  HAVEN'T SEEN IT  OKAY
# Non-text characters: ["'", "'"]
#
# Sample:   SHE ACTUALLY ASKED IF IT WAS REAL  I WOULD'VE  PROBABLY ASKED THE SAME THING CONSIDERING YOU WERE IN CHUCK E  CHEESE
# Non-text characters: ["'"]
#
# Sample:  YEAH THAT'S YOU KNOW  OKAY
# Non-text characters: ["'"]
#
# Sample:   OH  GOD  YOU  ARE DAMN  CHEAP  CHEAP  CHEAP  ANYWAYS MOVING ON IT'S NOT  LIKE YOU'RE  POOR  I  MEAN YOUR DAD MAKES  OKEY
# Non-text characters: ["'", "'"]
#
# Sample:  ISN'T IT A RAT IT'S A RAT  CHUCK E CHEESE
# Non-text characters: ["'", "'"]
#
# Sample:   OH THAT'S KIND OF SWEET
# Non-text characters: ["'"]
#
# Sample:  WAIT WAIT WAIT  I WANT YOU TO MARRY ME  NO  SHOULDN'T YOU LIKE  BE MORE  LIKE A QUESTION LIKE  WOULD YOU MARRY ME  NOT LIKE I WANT YOU TO MARRY ME IT'S LIKE A DEMAND
# Non-text characters: ["'", "'"]
#
# Sample:   SURE  WHO SAYS SURE YOU SAY YES  I  DON'T LIKE
# Non-text characters: ["'"]
#
# Sample:  I COULDN'T I COULDN'T AFFORD THE RED LOBSTER  LAUGHTER  WHAT ANYWAY
# Non-text characters: ["'", "'"]
#
# Sample:   CHUCKY  I DON'T  KNOW  I DON'T KNOW  ANYWAYS  I PULL HER UP  AND I GO  I GO SARAH
# Non-text characters: ["'", "'"]
#
# Sample:   YOU'RE MY GUIDING LIGHT  THEN  THEY  PUT ON THAT SONG THE I'VE HAD  THE  TIME OF MY LIFE THAT  SONG
# Non-text characters: ["'", "'"]
#
# Sample:  YOU  GOT TO MEET HER SHE'S WONDERFUL
# Non-text characters: ["'"]
#
# Sample:  SHE JUST GRADUATED  FROM HIGH SCHOOL AND  SHE'S  PLANNING TO APPLY FOR COLLEGES  AND  STUFF  SHE'S SO  GREAT SHE HAS SO MUCH LIFE  AND ENERGY AND  STUFF
# Non-text characters: ["'", "'"]
#
# Sample:  I'M TWENTY  EIGHT YEARS OLD
# Non-text characters: ["'"]
#
# Sample:  I'M SO EXCITED IT'S  GOING TO  BE  GREAT
# Non-text characters: ["'", "'"]
#
# Sample:  I'M STILL  WORKING AT MY PARENTS' RESTAURANT  BUSING TABLES
# Non-text characters: ["'", "'"]
#
# Sample:  OH  THAT'S GREAT  MY MOM SAID WE CAN MOVE IN WITH HER AGAIN  IF WE  RUN OUT OF MONEY
# Non-text characters: ["'"]
#
# Sample:  AUGIE  GODDAMN IT DON'T ASK ME THAT YOU ALWAYS ASK ME THAT WHY DO YOU  ASK  ME THAT I HATE IT  IT'S INSULTING
# Non-text characters: ["'", "'"]
#
# Sample:  LIKE I FEEL LIKE MY WHOLE  LIFE  I'VE BEEN JUST STANDING ON THIS  BEACH WITH  MY HANDS  CLASPED WAITING  FOR THESE  FISH TO SHOW UP AND THESE FISH NEVER SHOW UP
# Non-text characters: ["'"]
#
# Sample:  I  TOLD MYSELF  FINALLY  THIS IS  HOW HAPPY I'M SUPPOSED TO BE
# Non-text characters: ["'"]
#
# Sample:  I DON'T WANT TO REMEMBER SOMETHING
# Non-text characters: ["'"]
#
# Sample:   NO IT'S NOT IT'S  STANDING ON THE BEACH  WAITING AND FIGHTING
# Non-text characters: ["'", "'"]
#
# Sample:   IT'S NOT SOMETHING ELSE DO YOU KNOW WHAT I'M  TRYING TO SAY
# Non-text characters: ["'", "'"]
#
# Sample:   I  KNOW YOU ARE  AUGIE AND  I  KNOW YOU WANTED THIS EVENING TO BE  NICE  BUT I CAN'T HELP THINKING OF BEING SOMEWHERE  ELSE
# Non-text characters: ["'"]
#
# Sample:  I  DIDN'T SAY THAT
# Non-text characters: ["'"]
#
# Sample:   WELL  I  GUESS  WE'RE JUST IN THE WRONG SPART  SPOT WITH  THE RIGHT  PERSON
# Non-text characters: ["'"]
#
# Sample:   I NOTICED THAT IT'S  BEAUTIFUL
# Non-text characters: ["'"]
#
# Sample:  AT  LEAST WE WON'T NEED GLASSES
# Non-text characters: ["'"]
#
# ...
# Non-text characters: ["'"]
#
# Sample:  BUT UH  I DON'T SEE IT HERE IN THE AIRPORT YET  UH
# Non-text characters: ["'"]
#
# Sample:  I'M NOT SURE WHERE IT IS WE CAN  ABSOLUTELY KEEP AN EYE OUT FOR FOR IT FOR YOU
# Non-text characters: ["'"]
#
# Sample:  WELL I'M NOT A MIRACLE WORKER I DON'T KNOW WHAT I CAN DO FOR YOU  I  DON'T HAVE THE BAG  RIGHT HERE
# Non-text characters: ["'", "'", "'"]
#
# Sample:   WELL AS I TOLD YOU IT  LEFT  HEATH ROW  AND IT  SEEMS TO  HAVE  ARRIVED HERE BUT IF YOU CAN'T FIND IT THEN  ARE YOU SURE YOU KNOW WHAT YOUR BAG  LOOKS LIKE
# Non-text characters: ["'"]
#
# Sample:  ALL RIGHT  NOW  UM  IT'S  GREEN  TRAVEL BAG  YOU  COULDN'T FIND IT  AND WAS THERE SOMETHING  IMPORTANT IN IT THAT YOU  NEED  IT
# Non-text characters: ["'", "'"]
#
# Sample:   RIGHT  WELL I DON'T KNOW WHAT TO TELL YOU  UM  WHAT I CAN OFFER YOU  IS  A  FIFTY DOLLAR VOUCHER ON  YOUR NEXT FLIGHT
# Non-text characters: ["'"]
#
# Sample:  NO I UNDERSTAND I MEAN IT'S GOT TO BE TOUGH ALL THOSE SENTIMENTAL  THINGS BUT  UM  THIS IS ALL I CAN DO FOR YOU
# Non-text characters: ["'"]
#
# Sample:   WELL  YOU KNOW  SOMETIMES THAT'S  REALLY I MEAN WHAT ELSE COULD WE DO
# Non-text characters: ["'"]
#
# Sample:  LET'S  LET'S JUST RELAX FOR A MOMENT MA'AM YOU UNDERSTAND OBVIOUSLY WE'RE GOING TO DO EVERYTHING WE CAN TO KEEP  ALL OF YOUR LUGGAGE  HERE
# Non-text characters: ["'", "'", "'", "'"]
#
# Sample:   OBVIOUSLY WE'RE NOT TRYING TO LOSE YOUR LUGGAGE DO YOU REALLY BELIEVE THAT WE'RE TRYING TO  LOSE YOUR LUGGAGE  MA'AM
# Non-text characters: ["'", "'", "'"]
#
# Sample:   WELL WE'RE TALKING ABOUT ONE BAG  YOU  PERSONALLY MADE IT HERE DIDN'T YOU
# Non-text characters: ["'", "'"]
#
# Sample:  WELL IT'S LIKE ANY KIND OF INSURANCE  YOU DON'T  WHEN YOU  GET IT  THEN YOU GET MORE  YOU KNOW LIKE IF YOU
# Non-text characters: ["'", "'"]
#
# Sample:   WELL OF COURSE NOT BECAUSE YOU'VE GOT YOUR BACKPACK WITH YOU THE WHOLE TIME  NOW IF YOU  YOU SAID THIS WAS A TRAVEL BAG WHY WEREN'T YOU CARRYING IT ON IF IT WAS SO IMPORTANT
# Non-text characters: ["'", "'"]
#
# Sample:  I'M SORRY MA'AM THERE'S NOTHING ELSE I CAN DO  MY HANDS ARE REALLY TIED HERE  I REALLY WISH THERE WAS SOMETHING ELSE I COULD  DO  FOR YOU
# Non-text characters: ["'", "'", "'"]
#
# Sample:   WELL I DON'T KNOW WHY YOU WOULDN'T BELIEVE THAT
# Non-text characters: ["'", "'"]
#
# Sample:   WELL I HAVE NO WAY TO GIVE YOU MORE MONEY  I'M GIVING YOU AS MUCH MONEY AS I  CAN  AND FIGURING AS FAR AS FIGURING OUT WHERE YOU  BAG IS
# Non-text characters: ["'"]
#
# Sample:  THE AIRLINE MAKES THESE RULES MOM  MA'AM
# Non-text characters: ["'"]
#
# Sample:  AND WHILE I REALLY WOULD LOVE TO BE ABLE TO HAND YOU YOUR BAG  RIGHT NOW  OBVIOUSLY I CAN'T DO THAT
# Non-text characters: ["'"]
#
# Sample:   SO YOU'D LIKE THE FIFTY DOLLAR VOUCHER
# Non-text characters: ["'"]
#
# Sample:  OKAY JUST FILL OUT THESE THREE FORMS  AND  UM  YOU'LL WE'LL HAVE THAT SENT TO YOU  WITHIN THE NEXT THREE WEEKS  AND OF COURSE WE'LL DEFINITELY KEEP AN EYE OUT FOR YOUR  BAG
# Non-text characters: ["'", "'", "'"]
#
# Sample:  I'M SORRY IT'S  JUST A LOT AHH  TO EXPLAIN  AHH I GOT A  CALL
# Non-text characters: ["'", "'"]
#
# Sample:  I'M GOING TO NEED TO GO OVERSEAS FOR A WHILE
# Non-text characters: ["'"]
#
# Sample:   I DON'T KNOW  SIGH
# Non-text characters: ["'"]
#
# Sample:   I KNOW WELL WE'LL HAVE TO  FIGURE ALL THAT OUT  I MEAN  I  THINK THE ARMY'S GOING TO  PROVIDE CHILDCARE  AND HELP US OUT WITH THAT  UM
# Non-text characters: ["'", "'"]
#
# Sample:  I THINK INFANTRY I'M NOT SURE
# Non-text characters: ["'"]
#
# Sample:  I  DON'T THINK THERE'S ANYTHING WE CAN  DO
# Non-text characters: ["'", "'"]
#
# Sample:   I KNOW  I  KNOW IT'S NOT FAIR
# Non-text characters: ["'"]
#
# Sample:  WE'LL FIGURE SOMETHING OUT WE JUST HAVE TO  WE  JUST HAVE TO THINK ABOUT THIS  COULD ANY OF YOUR FAMILY HELP US
# Non-text characters: ["'"]
#
# Sample:  I'M GOING  TO MISS THEIR FIRST WORDS
# Non-text characters: ["'"]
#
# Sample:  YOU'LL HAVE TO SEND ME PICTURES AND LETTERS EVERYDAY
# Non-text characters: ["'"]
#
# Sample:   I LOVE YOU  I'M  GOING TO MISS YOU SO MUCH  SIGH
# Non-text characters: ["'"]
#
# Sample:  I THOUGHT YOU SAID THIS WASN'T GOING TO HAPPEN FOR AT LEAST A YEAR
# Non-text characters: ["'"]
#
# Sample:   I DON'T UNDERSTAND WHY THEY WOULD JUST  DO SOMETHING LIKE THIS
# Non-text characters: ["'"]
#
# Sample:  IT DOESN'T MAKE ANY SENSE IT'S STUPID  I  TOLD YOU YOU SHOULDN'T  GO IN THE ARMY
# Non-text characters: ["'", "'", "'"]
#
# Sample:   I'LL TELL THEM I'M SICK AND THAT YOU CAN'T LEAVE  SOMETHING
# Non-text characters: ["'", "'", "'"]
#
# Sample:  IT'S  NOT  FAIR
# Non-text characters: ["'"]
#
# Sample:  WHY HAS  TO  BE  YOU  THERE'S  ALL THOSE OTHER PEOPLE SOMEBODY ELSE CAN GO INSTEAD  IT'S NOT RIGHT
# Non-text characters: ["'", "'"]
#
# Sample:  I UNDERSTAND  I'M  WORRIED ABOUT YOU I DON'T KNOW WHAT'S GOING TO HAPPEN TO YOU
# Non-text characters: ["'", "'", "'"]
#
# Sample:  I DON'T  KNOW
# Non-text characters: ["'"]
#
# Sample:   YEAH  I  GUESS  I  DON'T KNOW WHAT THEY'RE GOING TO SAY
# Non-text characters: ["'", "'"]
#
# Sample:  YEAH  WE'LL CALL THEM  WE'LL FIGURE SOMETHING OUT I'M SORRY I'M  SORRY I'M  SORRY  YOU'RE RIGHT
# Non-text characters: ["'", "'", "'", "'", "'", "'"]
#
# Sample:  I  STILL  CAN'T LIVE ON IN SIX SEVEN AND  FIVE IT'S NOT POSSIBLE IN LOS ANGELES  HOUSING IS TOO EXPENSIVE
# Non-text characters: ["'", "'"]
#
# Sample:  I'M JUST SO SCARED TO START OVER I MEAN  I  PUT SO MUCH TIME AND ENERGY INTO BEING HERE
# Non-text characters: ["'"]
#
# Sample:  I  DON'T  KNOW  MAYBE I CAN TAKE OUT A LOAN I JUST I NEED PROSPECTS AND I DON'T FEEL LIKE I HAVE ANY
# Non-text characters: ["'", "'"]
#
# Sample:  I'M  JUST  WORRIED
# Non-text characters: ["'"]
#
# Sample:   THAT'S REALLY HARD TO HEAR
# Non-text characters: ["'"]
#
# Sample:   WELL I'D LIKE TO BE A WORKING ACTOR
# Non-text characters: ["'"]
#
# Sample:  WOULD YOU BE WILLING TO MAKE SOME MORE  CALLS  ON MY  BEHALF  I WON'T  I WON'T MAKE YOU LOOK  BAD
# Non-text characters: ["'", "'"]
#
# Sample:  BABE I DON'T KNOW WHAT TO TELL YOU  DON'T  GIVE UP
# Non-text characters: ["'", "'"]
#
# Sample:  NOTHING'S IMPOSSIBLE
# Non-text characters: ["'"]
#
# Sample:   NO IT DOESN'T PAY THE BILLS BUT IT WOULD PAY SOMETHING  AND IT WOULD HELP YOU GET SOMEWHERE ELSE
# Non-text characters: ["'"]
#
# Sample:  AND NO I UNDERSTAND BUT YOU'VE GOT TO  START SOMEWHERE IT'S BETTER THAN NOTHING AND THAT'S ALL YOU HAVE YOU HAVE NOTHING RIGHT NOW
# Non-text characters: ["'", "'", "'"]
#
# Sample:  WAIT  YOU CAN MOVE UP THERE'S MANAGEMENT PROGRAMS IN MCDONALDS AND  THINGS LIKE THAT
# Non-text characters: ["'"]
#
# Sample:  GARBAGE  NO I WOULDN'T  BUT I
# Non-text characters: ["'"]
#
# Sample:  HAVE YOU  THERE'S GOT TO BE SOMETHING ELSE
# Non-text characters: ["'"]
#
# Sample:  IF IT'S RENT OR SOMETHING LIKE THAT I MEAN I CAN HELP YOU OUT A LITTLE BIT  IF  IF THAT WILL HELP  YOU  YOU KNOW STICK WITH IT
# Non-text characters: ["'"]
#
# Sample:   WELL  JUST DON'T GIVE UP AND THERE'S  YOU KNOW  YOU NEVER KNOW SOMETHING MIGHT BE AROUND THE CORNER TOMORROW
# Non-text characters: ["'", "'"]
#
# Sample:  WELL  YOU KNOW I'M NOT GOING TO LET YOU STARVE
# Non-text characters: ["'"]
#
# Sample:  IT'S THE WAY IT SEEMS TO ME  YOU  STARTED COMPLAINING ABOUT NOT BEING ABLE TO FIND A JOB  THE FIRST DAY YOU WENT OUT AND DIDN'T FIND A JOB  AND I'M NOT SAYING  LIKE  AND NOT TRYING TO YOU KNOW  PUT YOU DOWN OR ANYTHING  IT'S JUST THAT
# Non-text characters: ["'", "'", "'", "'"]
#
# Sample:   YOU KNOW I WOULD NEVER LET THAT HAPPEN  I WOULDN'T LET THAT HAPPEN
# Non-text characters: ["'"]
#
# Sample:  YOU CAN ALWAYS STAY WITH ME IF YOU  IF YOU HAVE TO STAY WITH ME FOR A WHILE AND GET YOURSELF  BACK UP ON YOUR FEET AGAIN  YOU KNOW I'M NOT JUST GOING TO YOU KNOW JUST  THROW YOU TO THE WOLVES OR SOMETHING LIKE THAT  IF THERE'S ANY WAY I CAN HELP YOU I WILL
# Non-text characters: ["'", "'"]
#
# Sample:  BUT YOU HAVE TO KEEP  TRYING YOU  CAN'T GIVE UP
# Non-text characters: ["'"]
#
# Sample:   AND YOU'VE GOT TO THINK  WELL ASK YOURSELF WHY ARE THEY NOT HIRING YOU
# Non-text characters: ["'"]
#
# Sample:  HAVE YOU EVER CALLED THEM BACK  AND  ASKED WHY YOU DIDN'T GET THE JOB
# Non-text characters: ["'"]
#
# Sample:  DO THEY GIVE YOU ANY SPECIFICS AS TO WHY THEY DIDN'T GO WITH YOU
# Non-text characters: ["'"]
#
# Sample:  LIKE WHAT'S YOUR IDEAL JOB  WHAT DO YOU WANT TO DO
# Non-text characters: ["'"]
#
# Sample:  SO WHAT'S THE SOMETHING ELSE
# Non-text characters: ["'"]
#
# Sample:  YOU CAN'T GET A CATERING GIG  WELL I CAN CALL SOME FRIENDS  I  WELL  I DID CALL SOME FRIENDS BEFORE  BUT  YOU  WENT IN ONCE  AND THEN NEVER WENT BACK
# Non-text characters: ["'"]
#
# Sample:  OKAY  OKAY I'LL CALL SOME PEOPLE
# Non-text characters: ["'"]
#
# Sample:  BUT YOU'VE GOT TO KEEP LOOKING FOR OTHER STUFF  YOU'VE GOT TO DO IT ON YOUR OWN TOO  OKAY
# Non-text characters: ["'", "'"]
#
# Sample:   YOU KNOW I'LL ALWAYS HELP YOU
# Non-text characters: ["'"]
#
# Sample:   YEAH SO I CAN'T  I CAN'T DO ANYTHING
# Non-text characters: ["'", "'"]
#
# Sample:   NO I UNDERSTAND AND THERE ARE A LOT OF PEOPLE HERE BUT  WHAT I'M TELLING YOU IS THAT  IT'S DIFFERENT FOR DIFFERENT STATES AND SINCE YOUR GETTING A NEW LICENSE IN THE  STATE OF CALIFORNIA  YOU HAVE TO FILL OUT A DIFFERENT FORM THAN YOU DID
# Non-text characters: ["'", "'"]
#
# Sample:  YEAH I KNOW IT'S GONNA TAKE A MINUTE BUT YOU SO YOU MIGHT AS WELL GET STARTED NOW
# Non-text characters: ["'"]
#
# Sample:  I'M  GONNA I'M  GONNA BRING SECURITY OVER AND HAVE THEM ESCORT YOU OUT
# Non-text characters: ["'", "'"]
#
# Sample:   WELL THAT'S UNFORTUNATE SIR YOU'RE GONNA HAVE TO GO STAND IN THE OTHER LINE  NOW
# Non-text characters: ["'", "'"]
#
# Sample:   I'M NOT GETTING  A WELL YOU WAIT IN THIS LINE AND NOT GET AN ATTITUDE
# Non-text characters: ["'"]
#
# Sample:  WOULDN'T YOU  OH COME ON  YOU JUST TELL ME  YOU WOULD MAKE AN EXCEPTION  FOR  ME
# Non-text characters: ["'"]
#
# Sample:  OH  I'M  SO  SORRY
# Non-text characters: ["'"]
#
# Sample:  YEAH  I'M SO  SORRY
# Non-text characters: ["'"]
#
# Sample:  I'M  SORRY  I
# Non-text characters: ["'"]
#
# Sample:  WOW  RYAN I KNOW THAT  YOU ARE  HURTING RIGHT NOW  BUT  I  DON'T THINK YOU ALWAYS FEEL LIKE  THAT
# Non-text characters: ["'"]
#
# Sample:  YEAH  I UNDERSTAND I  THINK IT'S  REALLY HEALTHY TO GRIEVE
# Non-text characters: ["'"]
#
# Sample:  IF THERE'S  ANYTHING I  CAN  DO  TO BE THERE FOR YOU
# Non-text characters: ["'"]
#
# Sample:  THE END  HE'S BEEN SICK FOR AWHILE HE  HAD CANCER
# Non-text characters: ["'"]
#
# Sample:  YEAH  IT'S JUST  I  NEVER THOUGHT IT WOULD ACTUALLY HAPPEN YOU KNOW I MEAN  HE'S  SUCH A FIGHTER AND HE'S ALWAYS SO POSITIVE ABOUT EVERYTHING
# Non-text characters: ["'", "'", "'"]
#
# Sample:  HE  WANTED TO TRAVEL YOU KNOW AND  HE'S SO  TALENTED PROBABLY THE MOST TALENTED PERSON I HAVE EVER MET IN MY ENTIRE LIFE
# Non-text characters: ["'"]
#
# Sample:  AND  HE'S GONE NOW AND I I  JUST  CAN'T  BELIEVE IT
# Non-text characters: ["'", "'"]
#
# Sample:  I  MEAN  ONE SECOND YOU THINK  YOU KNOW YOU'RE  JUST HAVING A CONVERSATION AND THEN
# Non-text characters: ["'"]
#
# Sample:   YOU KNOW  SOMETIMES YOU THINK  YOU  WANT TO MAKE THAT PHONE CALL OR  YOU THINK YOU WANT TO TELL SOMEBODY SOMETHING OR SOMETHING LIKE THAT DO YOU KNOW WHAT I MEAN  LIKE THAT'S  HE WAS THE PERSON  THAT I DID THAT WITH YOU KNOW LIKE  THAT'S THE PERSON WHO I NEEDED TO CALL TO TELL THINGS TO ALL THE TIME
# Non-text characters: ["'", "'"]
#
# Sample:  AND NOW I DON'T HAVE THAT  PERSON ANYMORE  YOU KNOW AND IT'S  IT'S  JUST  YOU
# Non-text characters: ["'", "'", "'"]
#
# Sample:  AND IT JUST GETS WORSE IT JUST GETS WORSE EVERYTHING IS BAD  ALL THE TIME  PEOPLE DIE YOUR  FRIENDS DIE FAMILY DIES YOUR BEST FRIENDS DIE  IT'S
# Non-text characters: ["'"]
#
# Sample:  NO YOU'RE RIGHT I DON'T  YOU'RE RIGHT
# Non-text characters: ["'", "'", "'"]
#
# Sample:  EVEN  YEAH  HE DOESN'T  HE WOULD NEVER FEEL THAT WAY HE WOULD NEVER WANT ME TO FEEL THAT WAY OF  COURSE NOT  BUT  THAT'S JUST WHERE I AM RIGHT NOW AND I  DON'T KNOW WHAT ELSE TO DO WITH IT
# Non-text characters: ["'", "'", "'"]
#
# Sample:  WELL IT GAVE HIM A LOT OF PLEASURE AND IT DIDN'T HURT ME
# Non-text characters: ["'"]
#
# Sample:  IT'S BECOMING A HABIT WITH YOU
# Non-text characters: ["'"]
#
# Sample:  NO IT ISN'T
# Non-text characters: ["'"]
#
# Sample:  YOU KNOW WHAT  I'M SICK AND TIRE  OF LISTENING TO YOU YOU'RE  A  YOU'RE A TOTAL SADISTIC  BULLY
# Non-text characters: ["'", "'", "'"]
#
# Sample:  STOP  WOULD YOU JUST  GO AWAY I MEAN YOU'RE  CONCEITED AND OVERBEARING AND UTTERLY IMPOSSIBLE
# Non-text characters: ["'"]
#
# Sample:  WELL THAT'S A NICE POINT OF VIEW I MUST SAY
# Non-text characters: ["'"]
#
# Sample:  I THINK I'LL HAVE A LITTLE
# Non-text characters: ["'"]
#
# Sample:   IT'S A PITY YOU DIDN'T HAVE A LITTLE BIT MORE BRANDY IT MIGHT HAVE MADE YOU A  LITTLE  LESS DISAGREEABLE
# Non-text characters: ["'", "'"]
#
# Sample:   I'M SURE YOU HAD A RIOTOUS TIME  NO RESTRAIN AT ALL  VERY ENJOYABLE YOU NEVER HAD MUCH ANYWAY
# Non-text characters: ["'"]
#
# Sample:   I  DO BELIEVE THAT I  HAVE SAID ALREADY THAT I  HAD  THREE  MINUET  LIQUOR  GLASSES OF  BRANDY IN THE ENTIRE  EVENING A CHILD OF  TWO  COULDN'T GET DRUNK OF THAT
# Non-text characters: ["'"]
#
# Sample:   YOU KNOW WHAT THAT'S A  VERY GOOD IDEA  I THINK  I  WILL
# Non-text characters: ["'"]
#
# Sample:   BECAUSE IT'S VERY LATE AND YOU'LL DISTURB THE PEOPLE UPSTAIRS
# Non-text characters: ["'", "'"]
#
# Sample:  TURN IT  OFF  IT'S DRIVING ME MAD
# Non-text characters: ["'"]
#
# Sample:  OH YOU'RE NOT GOING LIKE  THIS
# Non-text characters: ["'"]
#
# Sample:  GARBAGE  NO  YOU'RE NOT
# Non-text characters: ["'"]
#
# Sample:  OH  MARRY  YOU AGAIN I WOULDN'T MARRY YOU AGAIN IF YOU CAME CRAWLING TO ME ON BENDED KNEE
# Non-text characters: ["'"]
#
# Sample:  YOU'RE A  WICKED LITTLE VAMPIRE AND  I  PRAY TO GOD I NEVER SET EYES ON YOU AGAIN AS  LONG AS  I  LIVE
# Non-text characters: ["'"]
#
# Sample:   METASTASIZED AND IT WAS  OLD AND THEY KNEW  THAT IT WASN'T LOOKING GOOD BUT
# Non-text characters: ["'"]
#
# Sample:   IT'S HARD TO WATCH WHEN IT'S  PAINFUL FOR THEM YOU KNOW
# Non-text characters: ["'", "'"]
#
# Sample:  I  JUST  I DON'T KNOW
# Non-text characters: ["'"]
#
# Sample:   I  CAN'T IMAGINE WHAT HIS  WHAT HIS PARENTS ARE GOING  THROUGH
# Non-text characters: ["'"]
#
# Sample:   YEAH I'M JUST GOING TO MISS HIM
# Non-text characters: ["'"]
#
# Sample:  YEAH THEY'RE  GOING TO DO SOME SORT OF MEMORIAL  SERVICE OR SOMETHING
# Non-text characters: ["'"]
#
# Sample:   IT'S REALLY BIZARRE YOU KNOW WHEN YOU KNOW SOMEBODY REALLY WELL AND THEN
# Non-text characters: ["'"]
#
# Sample:   SOMETHING HAPPENS AND  THEY DIE AND IT'S LIKE
# Non-text characters: ["'"]
#
# Sample:  REALLY HARD TO IMAGINE THAT  LIKE  YOU'RE GOING TO CONTINUE TO LIVE AND THAT PERSON'S JUST GOING TO HAVE  STOPPED
# Non-text characters: ["'", "'"]
#
# Sample:   IT'S  HARD TO SAY GOOD BYE
# Non-text characters: ["'"]
#
# Sample:  OH  NO I'M SO SORRY  WHAT  HAPPENED
# Non-text characters: ["'"]
#
# Sample:  THAT'S THE  WORST  I'M  SO SORRY  DID YOU KNOW HIM WELL
# Non-text characters: ["'", "'"]
#
# Sample:  I  AM  SO  SORRY  IT'S
# Non-text characters: ["'"]
#
# Sample:  IT'S THE WORST WHEN THEY  GO LIKE THAT  GARBAGE  WAS  HE YOUNG
# Non-text characters: ["'"]
#
# Sample:  IT'S THE  THINK
# Non-text characters: ["'"]
#
# Sample:  THERE'S NO REASON  FOR IT
# Non-text characters: ["'"]
#
# Sample:  YEAH  WHAT'D HE DO  WHAT DID THEY  DO  HOW'D YOU KNOW HIM
# Non-text characters: ["'", "'"]
#
# Sample:  OF  COURSE NOT  YOU  HAVE NO IDEA WHAT IT'S LIKE TO LOSE A KID
# Non-text characters: ["'"]
#
# Sample:  RIGHT  IT JUST DOESN'T MAKE ANY SENSE  IT'S NOT REAL  IT DOESN'T FEEL REAL
# Non-text characters: ["'", "'", "'"]
#
# Sample:  DO YOU KNOW WHAT  IT'S GOING TO PASS  EVENTUALLY  I MEAN  IT'LL NEVER PASS IT'LL ALWAYS BE THERE AND  YOU'LL ALWAYS REMEMBER AND EVERYTHING LIKE THAT  BUT  YOU KNOW  IT'LL GET EASIER I  GUESS
# Non-text characters: ["'", "'", "'", "'", "'"]
#
# Sample:  THAT'S  THE  BEST WAY TO  PUT IT
# Non-text characters: ["'"]
#
# Sample:   DO YOU KNOW WHAT  IF IT WAS ME THAT DIED I'D  REALLY WANT YOU TO BE CRYING AND  BEING REALLY UPSET TOO ANY WAY  SO  I THINK YOU SHOULD DEFINITELY  DO  THIS  BECAUSE IT'S TRYING  WHAT IT'S SUPPOSED TO BE
# Non-text characters: ["'", "'", "'"]
#
# BREATHING: 0,LAUGHTER:0,GARBAGE:0

# %% [markdown]
# # **BLSTM Based Unimodal Models**
#
# **Note: Same models will be used for the lexical only and audio only classification**

# %% [markdown]
# ### **Model I -output of the final BLSTM block**

# %%
# use the output of the final BLSTM  block for the classification
class BLSTM_lastblock(nn.Module):
    def __init__(self, input_dim, hidden_dim,num_layers, num_classes):
        super().__init__()
        self.rnn = nn.LSTM(input_size=input_dim,hidden_size=hidden_dim,num_layers=num_layers,
                           batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, num_classes)

    def forward(self, x,lengths):
        # Pack the padded sequence
        x = torch.nn.utils.rnn.pack_padded_sequence(x, lengths, batch_first=True, enforce_sorted=False)
        # Pass the packed sequence through the LSTM
        x, _ = self.rnn(x)
        # Unpack the packed sequence
        x, _ = torch.nn.utils.rnn.pad_packed_sequence(x, batch_first=True)
        # Select the output of the final LSTM block
        x = x[torch.arange(x.size(0)), lengths - 1, :]
        # Pass the output through the linear layer for classification
        x = self.fc(x)
        return x

# %%
# use the output of the final BLSTM  block for the classification
class BLSTM_CLSblock(nn.Module):
    def __init__(self, input_dim, hidden_dim,num_layers, num_classes):
        super().__init__()
        self.rnn = nn.LSTM(input_size=input_dim,hidden_size=hidden_dim,num_layers=num_layers,
                           batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, num_classes)

    def forward(self, x,lengths):
        # Pack the padded sequence
        x = torch.nn.utils.rnn.pack_padded_sequence(x, lengths, batch_first=True, enforce_sorted=False)
        # Pass the packed sequence through the LSTM
        x, _ = self.rnn(x)
        # Unpack the packed sequence
        x, _ = torch.nn.utils.rnn.pad_packed_sequence(x, batch_first=True)
        # Select the output of the final LSTM block
        x = x[torch.arange(x.size(0)), 0, :]
        # Pass the output through the linear layer for classification
        x = self.fc(x)
        return x

# %% [markdown]
# ### **Model II -Using averaging pooling**

# %%
# use average pooling of the outputs of the BLSTM block for classification
class BLSTM_avg_pooling(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, num_classes):
        super().__init__()
        self.rnn = nn.LSTM(input_size=input_dim, hidden_size=hidden_dim, num_layers=num_layers,
                           batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, num_classes)

    def forward(self, x, lengths):
        # Pack the padded sequence
        x = torch.nn.utils.rnn.pack_padded_sequence(x, lengths, batch_first=True, enforce_sorted=False)
        # Pass the packed sequence through the LSTM
        x, _ = self.rnn(x)
        # Unpack the packed sequence
        x, _ = torch.nn.utils.rnn.pad_packed_sequence(x, batch_first=True)
        # Compute the average across the sequence dimension (axis=1)
        x = torch.mean(x, dim=1)
        # Pass the output through the linear layer for classification
        x = self.fc(x)
        return x

# %% [markdown]
# ### **Model III - Using context based attention pooling**

# %%
class ContextBasedAttention(nn.Module):
    def __init__(self, hidden_dim, attention_dim):
        super().__init__()
        self.wh = nn.Linear(hidden_dim, attention_dim)
        self.v = nn.Parameter(torch.rand(attention_dim, 1))
        self.tanh = nn.Tanh()
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        hi = self.wh(x)
        ei = self.tanh(hi).matmul(self.v)
        ai = self.softmax(ei)
        z = torch.sum(ai * x, dim=1)
        return z

class BLSTMWithContextBasedAttention(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, attention_dim, num_classes):
        super().__init__()
        self.rnn = nn.LSTM(input_size=input_dim, hidden_size=hidden_dim, num_layers=num_layers,
                           batch_first=True, bidirectional=True)
        self.attention = ContextBasedAttention(hidden_dim * 2, attention_dim)
        self.fc = nn.Linear(hidden_dim * 2, num_classes)

    def forward(self, x, lengths):
        # Pack the padded sequence
        x = torch.nn.utils.rnn.pack_padded_sequence(x, lengths, batch_first=True, enforce_sorted=False)
        # Pass the packed sequence through the LSTM
        x, _ = self.rnn(x)
        # Unpack the packed sequence
        x, _ = torch.nn.utils.rnn.pad_packed_sequence(x, batch_first=True)
        # Compute the attention based weighted average across the sequence dimension (axis=1)
        x = self.attention(x)
        x = self.fc(x)
        return x

# %% [markdown]
# # Acousitc Modality

# %%
# Prepare data for training
X = []
num_frames = []
for samp_feat in data['features']:
    samp_feat = np.array(samp_feat)
    num_frames.append(samp_feat.shape[0])
    X.append(samp_feat)

num_frames = pd.DataFrame(num_frames)
num_frames.describe()
# Out:
#                  0
# count  5520.000000
# mean    450.925725
# std     323.165689
# min      54.000000
# 25%     229.000000
# 50%     353.000000
# 75%     573.000000
# max    3409.000000

# %% [markdown]
# ### Audio Dataset Class

# %%
class IEMOCAP_audio(Dataset):

    def __init__(self, mean=None, std=None):
        # Initialize data, download etc.
        data = pd.read_pickle(data_pickel_path)
        self.x = [np.array(samp_feat) for samp_feat in data['features']]
        y = data['emotion'].values
        self.label_encoder = LabelEncoder()
        self.spk = data['spk'] 
        self.y = self.label_encoder.fit_transform(y)
        self.n_samples = data.shape[0]
        self.mean = mean
        self.std = std

    def __getitem__(self, index):
        x_ = torch.tensor(self.x [index])
        if self.mean is not None and self.std is not None:
            x_ = (x_ - self.mean) / self.std
        seq_size = x_.shape[0]
        return x_, torch.tensor(self.y[index]), seq_size

    def __len__(self):
        return self.n_samples

    def get_spk(self):
        return self.spk
        
    def get_encoder(self):
        return self.label_encoder

# %%
iemocap_dataset  = IEMOCAP_audio()
index = 400
print('label = ',iemocap_dataset[index][1])
print('sample feature_shape = ',iemocap_dataset [index][0].shape)
print('original sequence length = ',iemocap_dataset [index][2])
print('inverse label transform',iemocap_dataset.get_encoder().inverse_transform([0, 1, 2,3]))
iemocap_dataset[index]
# Out:
# label =  tensor(2)
# sample feature_shape =  torch.Size([690, 65])
# original sequence length =  690
# inverse label transform ['ang' 'hap' 'neu' 'sad']
# (tensor([[ 0.0000,  0.6169,  0.0000,  ..., -9.2440, -5.5332, -8.9552],
#          [ 0.0000,  0.6130,  0.0000,  ..., -4.1164, -1.0473, -9.4122],
#          [ 0.0000,  0.5902,  0.0000,  ..., -1.9275,  3.9153, -8.6798],
#          ...,
#          [ 0.0000,  0.5658,  0.0000,  ...,  1.1384,  6.4713, -5.1534],
#          [ 0.0000,  0.5709,  0.0000,  ..., -6.5104,  6.0755, -3.8702],
#          [ 0.0000,  0.5872,  0.0000,  ..., -2.5860,  9.4837, -6.2946]]),
#  tensor(2),
#  203)

# %% [markdown]
# **Custom Collate Function**

# %%
def custom_collate_fn(batch):
    features, labels,seq_lengths = zip(*batch)
    # seq_lengths = [len(seq) for seq in features]

    # Sort sequences by length in descending order
    seq_lengths, perm_idx = torch.tensor(seq_lengths).sort(0, descending=True)
    features = [features[i] for i in perm_idx]
    labels = torch.tensor([labels[i] for i in perm_idx])

    # Pad the sequences
    padded_features = pad_sequence(features, batch_first=True)
    return padded_features, labels, seq_lengths

# %% [markdown]
# **Randomly splitting the dataset and storing the test (20%) and train (80%) indices**

# %%
num_samp = len(iemocap_dataset)
train_size = int(0.8 * len(iemocap_dataset))
test_size = len(iemocap_dataset) - train_size
train_indices = random.sample(range(num_samp), train_size)
test_indices = [i for i in range(num_samp) if i not in train_indices ]
print("train_indices",train_indices)
print("test_indices",test_indices)
# Out:
# train_indices [5238, 912, 204, 2253, 2006, 1828, 1143, 839, 4467, 712, 4837, 3456, 260, 244, 767, 1791, 1905, 4139, 4931, 217, 4597, 1628, 5323, 4464, 3436, 1805, 3679, 4827, 2278, 53, 1307, 3462, 2787, 2276, 1273, 1763, 2757, 837, 759, 3112, 792, 2940, 2817, 4945, 2166, 355, 3763, 4392, 1022, 3100, 645, 4522, 2401, 5149, 5066, 2962, 4729, 1575, 569, 375, 5417, 1866, 2370, 653, 1907, 827, 3113, 2277, 3714, 5207, 2988, 1332, 3032, 2910, 1716, 2187, 5308, 584, 4990, 5201, 1401, 4375, 2005, 1338, 3786, 3108, 2211, 5242, 4562, 1799, 2656, 458, 1876, 262, 2584, 3286, 2193, 542, 1728, 4646, 2577, 1741, 5369, 4089, 3241, 5266, 3758, 1170, 2169, 5513, 2020, 4598, 4415, 2152, 4788, 3509, 4780, 3271, 2965, 1796, 1133, 4174, 4042, 744, 385, 898, 1252, 5140, 1310, 3458, 4885, 520, 3152, 3126, 4881, 3834, 4334, 2059, 4532, 94, 938, 4398, 2185, 5250, 2786, 913, 2404, 3561, 1295, 3716, 26, 2157, 4100, 1463, 4158, 871, 5122, 2444, 5234, 5365, 4988, 1629, 5393, 3063, 1323, 4418, 4344, 4, 4906, 2655, 4002, 159, 916, 2973, 2519, 1961, 474, 1973, 4647, 5469, 701, 3981, 566, 4363, 1030, 1051, 3893, 4503, 1352, 2171, 4322, 4969, 3466, 1735, 4417, 1647, 2553, 3268, 3059, 3588, 4239, 3698, 991, 2030, 1840, 524, 2769, 172, 4819, 4537, 1885, 4820, 1804, 58, 581, 5169, 482, 1875, 552, 257, 2706, 580, 4211, 1949, 2281, 3976, 1755, 5325, 1083, 4677, 4720, 3872, 1990, 3874, 3334, 1559, 772, 794, 3531, 2902, 3469, 3367, 3825, 443, 806, 496, 3298, 2779, 895, 2036, 1569, 1558, 4393, 3675, 1148, 5508, 1503, 5295, 3789, 2046, 617, 3630, 4508, 802, 414, 4428, 120, 764, 1936, 1362, 3329, 3978, 3943, 1751, 3285, 480, 1348, 3104, 17, 3198, 2172, 3727, 2336, 3465, 4552, 3986, 1268, 1555, 2430, 1783, 479, 4744, 4441, 499, 2569, 468, 410, 4785, 3905, 4119, 4350, 1289, 465, 4160, 656, 1522, 561, 4874, 556, 1926, 3307, 982, 4666, 2016, 4742, 4870, 325, 5073, 671, 3434, 4781, 4630, 4282, 2591, 2136, 1673, 2573, 1955, 2175, 3242, 1072, 2457, 3745, 2590, 594, 76, 3754, 5088, 4612, 819, 600, 4404, 1746, 4144, 5239, 1085, 2859, 563, 2001, 3027, 2334, 1292, 3589, 4450, 2478, 5010, 4333, 64, 4543, 2452, 848, 1100, 5475, 945, 876, 5381, 5485, 2231, 2308, 4954, 1725, 2808, 1667, 2162, 4140, 5349, 2057, 416, 756, 5279, 2266, 361, 29, 2732, 1071, 2145, 5355, 3619, 4519, 3503, 4594, 79, 5347, 616, 1221, 4469, 295, 3024, 4771, 4526, 1213, 3520, 1044, 342, 2525, 2987, 326, 2931, 1720, 2044, 842, 2897, 4586, 5249, 5084, 1266, 1939, 1331, 1450, 3377, 203, 1469, 2721, 3372, 2032, 5377, 1304, 885, 3133, 317, 3855, 1822, 1634, 3770, 2864, 2500, 1864, 1826, 193, 1582, 3264, 2689, 2282, 568, 2286, 2876, 4173, 3274, 5472, 2712, 226, 944, 2139, 1462, 4756, 2174, 313, 888, 4887, 3559, 2831, 5225, 3574, 4966, 4189, 947, 3155, 4723, 1557, 2086, 363, 3572, 13, 4259, 4410, 1614, 2983, 3533, 573, 2704, 2571, 1020, 2460, 4154, 2533, 3345, 2672, 3296, 2422, 4541, 1042, 1571, 3444, 3105, 1425, 4662, 2465, 3326, 4488, 3, 2489, 2350, 1721, 3521, 4751, 5328, 2639, 3809, 5132, 3622, 1750, 4187, 3876, 1390, 694, 2324, 4222, 2745, 765, 1924, 2542, 5315, 1631, 1207, 200, 378, 5437, 3892, 596, 3730, 3395, 4715, 1592, 3145, 4049, 3273, 1998, 1208, 45, 873, 3482, 1792, 1440, 4243, 3805, 411, 4566, 2041, 994, 3739, 1092, 3806, 4351, 4578, 4877, 2599, 3625, 4135, 3495, 5021, 3652, 1303, 3888, 3686, 2123, 2025, 2271, 4270, 3969, 1959, 2249, 3603, 634, 2340, 1920, 2225, 2751, 2619, 4424, 660, 5399, 1235, 1894, 3137, 1251, 1752, 526, 3398, 3339, 2710, 4445, 3816, 3406, 510, 1694, 3441, 3190, 4784, 160, 4716, 3116, 3907, 48, 2881, 2446, 3194, 3432, 4409, 4473, 1806, 3999, 1797, 2235, 3570, 5248, 237, 3185, 2753, 3312, 5331, 3828, 1045, 5438, 220, 3227, 4848, 4623, 222, 687, 3511, 1111, 3782, 1488, 4974, 2131, 5026, 2681, 1733, 3724, 2677, 2764, 4884, 2279, 3453, 2066, 670, 3852, 158, 5354, 426, 2866, 1836, 562, 329, 254, 5150, 1633, 166, 1248, 1954, 1034, 3879, 937, 4620, 1785, 5012, 2099, 3021, 1374, 5379, 1341, 2548, 5092, 4740, 210, 2555, 4920, 3074, 3249, 1624, 622, 1989, 834, 2470, 5317, 4636, 336, 2844, 4364, 5 ...
# test_indices [0, 8, 11, 20, 22, 28, 30, 31, 32, 35, 36, 42, 47, 51, 54, 55, 61, 65, 69, 73, 75, 78, 80, 81, 84, 85, 86, 88, 95, 96, 97, 99, 102, 104, 105, 108, 117, 123, 128, 136, 139, 140, 143, 144, 146, 147, 155, 162, 165, 177, 180, 189, 191, 194, 197, 202, 224, 225, 228, 232, 238, 239, 264, 266, 271, 272, 274, 284, 285, 287, 289, 292, 293, 296, 297, 305, 310, 312, 320, 331, 339, 358, 362, 364, 377, 379, 380, 386, 391, 392, 393, 395, 397, 402, 406, 409, 417, 427, 431, 435, 437, 441, 442, 445, 451, 456, 460, 469, 470, 472, 473, 481, 483, 489, 490, 494, 505, 506, 514, 515, 518, 537, 558, 587, 589, 592, 593, 595, 607, 608, 619, 621, 630, 638, 639, 640, 641, 642, 648, 666, 675, 676, 680, 696, 703, 708, 711, 715, 722, 723, 725, 729, 741, 742, 743, 752, 757, 758, 769, 773, 776, 779, 785, 788, 798, 805, 809, 824, 829, 830, 831, 836, 850, 851, 854, 860, 862, 866, 868, 869, 870, 880, 882, 896, 899, 901, 902, 910, 911, 915, 917, 922, 930, 933, 936, 939, 956, 957, 960, 961, 989, 995, 998, 1011, 1017, 1019, 1027, 1029, 1039, 1040, 1041, 1043, 1049, 1052, 1060, 1061, 1062, 1063, 1067, 1069, 1075, 1080, 1081, 1086, 1088, 1089, 1090, 1091, 1102, 1103, 1105, 1107, 1116, 1121, 1123, 1128, 1131, 1136, 1144, 1146, 1147, 1156, 1157, 1166, 1168, 1177, 1181, 1187, 1190, 1191, 1194, 1202, 1205, 1214, 1223, 1224, 1226, 1234, 1239, 1244, 1249, 1254, 1258, 1259, 1272, 1278, 1279, 1293, 1300, 1301, 1312, 1318, 1324, 1326, 1327, 1337, 1339, 1344, 1357, 1366, 1367, 1369, 1375, 1376, 1381, 1384, 1389, 1391, 1396, 1400, 1403, 1404, 1408, 1415, 1422, 1433, 1446, 1452, 1455, 1461, 1466, 1487, 1493, 1512, 1513, 1515, 1521, 1524, 1526, 1534, 1548, 1549, 1551, 1552, 1560, 1578, 1587, 1596, 1598, 1611, 1612, 1615, 1617, 1618, 1619, 1622, 1639, 1645, 1648, 1649, 1655, 1658, 1662, 1665, 1668, 1676, 1678, 1688, 1698, 1707, 1726, 1727, 1739, 1740, 1747, 1748, 1754, 1771, 1774, 1775, 1776, 1778, 1782, 1786, 1787, 1816, 1817, 1830, 1832, 1833, 1849, 1854, 1855, 1856, 1858, 1859, 1860, 1868, 1881, 1883, 1897, 1898, 1900, 1901, 1911, 1916, 1919, 1930, 1932, 1937, 1938, 1941, 1946, 1957, 1969, 1970, 1971, 1976, 1981, 1988, 1992, 1994, 2007, 2008, 2012, 2013, 2022, 2031, 2034, 2035, 2050, 2061, 2064, 2069, 2072, 2073, 2081, 2089, 2094, 2095, 2103, 2104, 2106, 2114, 2115, 2117, 2118, 2128, 2130, 2133, 2138, 2140, 2142, 2150, 2155, 2158, 2159, 2177, 2181, 2182, 2196, 2204, 2205, 2209, 2213, 2217, 2218, 2222, 2223, 2244, 2245, 2264, 2267, 2273, 2274, 2275, 2292, 2294, 2299, 2313, 2327, 2328, 2332, 2338, 2352, 2353, 2357, 2363, 2367, 2373, 2374, 2375, 2381, 2382, 2391, 2394, 2396, 2397, 2400, 2402, 2416, 2419, 2421, 2428, 2436, 2455, 2458, 2459, 2463, 2466, 2471, 2480, 2482, 2486, 2492, 2494, 2495, 2503, 2505, 2507, 2509, 2522, 2523, 2527, 2529, 2532, 2534, 2543, 2544, 2554, 2562, 2563, 2566, 2570, 2578, 2585, 2600, 2609, 2614, 2621, 2623, 2653, 2658, 2659, 2666, 2673, 2678, 2682, 2692, 2693, 2695, 2699, 2702, 2703, 2705, 2708, 2713, 2714, 2716, 2725, 2729, 2733, 2738, 2739, 2740, 2748, 2763, 2772, 2775, 2797, 2798, 2799, 2801, 2806, 2815, 2823, 2832, 2846, 2847, 2852, 2853, 2857, 2871, 2874, 2877, 2879, 2884, 2885, 2888, 2891, 2894, 2900, 2904, 2909, 2911, 2916, 2923, 2929, 2933, 2935, 2937, 2945, 2957, 2959, 2966, 2968, 2974, 2980, 2984, 2986, 2989, 2993, 2998, 2999, 3016, 3020, 3022, 3029, 3030, 3037, 3038, 3040, 3042, 3045, 3046, 3057, 3064, 3067, 3068, 3075, 3076, 3082, 3086, 3089, 3093, 3094, 3095, 3098, 3106, 3107, 3109, 3118, 3122, 3132, 3136, 3139, 3143, 3147, 3156, 3163, 3164, 3170, 3171, 3173, 3177, 3178, 3182, 3184, 3186, 3192, 3196, 3203, 3205, 3208, 3209, 3215, 3217, 3218, 3219, 3220, 3226, 3234, 3236, 3238, 3254, 3258, 3267, 3269, 3272, 3275, 3277, 3278, 3279, 3284, 3293, 3294, 3295, 3301, 3305, 3314, 3315, 3320, 3322, 3333, 3337, 3340, 3341, 3347, 3348, 3351, 3352, 3355, 3356, 3357, 3359, 3360, 3364, 3369, 3371, 3373, 3391, 3393, 3402, 3410, 3413, 3417, 3422, 3424, 3425, 3431, 3435, 3445, 3446, 3447, 3449, 3452, 3454, 3459, 3461, 3468, 3472, 3477, 3480, 3491, ...

# %%
batch_size = 32
train_dataset_unnormalized = torch.utils.data.Subset(iemocap_dataset, train_indices)
train_loader_unnormalized = DataLoader(dataset=train_dataset_unnormalized, batch_size=batch_size, shuffle=True,collate_fn=custom_collate_fn)

# %% [markdown]
# ### **Normalizing the Audio Data**

# %%
def calculate_mean_std(train_loader):
    running_sum = 0
    running_sum_sq = 0
    total_count = 0

    for i,batch in enumerate(train_loader):
        # if i <= 2:
        features_batch, labels_batch, seq_sizes_batch = batch
        for features, seq_size in zip(features_batch, seq_sizes_batch):
            features = features.numpy()
            # print(features[:seq_size].shape)
            # print(features[:seq_size].shape,features[:seq_size])
            running_sum += np.sum(features[:seq_size], axis=0)
            running_sum_sq += np.sum(features[:seq_size] ** 2, axis=0)
            total_count += seq_size

    mean = running_sum / total_count
    std = np.sqrt(running_sum_sq / total_count - mean ** 2)

    return mean, std

# %%
mean, std = calculate_mean_std(train_loader_unnormalized)
print(mean.shape,mean[:10])
print(std.shape,std[:10])
# Out:
# torch.Size([65]) tensor([ 8.5654e+01,  5.8080e-01,  1.0940e-02,  8.4625e-03,  6.1445e-02,
#         -5.3501e+01,  3.6119e-01,  1.1703e+00,  2.2729e-02,  1.0051e-01])
# torch.Size([65]) tensor([1.1668e+02, 2.7898e-01, 3.0493e-02, 2.7910e-02, 1.0592e-01, 5.2843e+01,
#         5.1323e-01, 6.8625e-01, 5.4571e-02, 7.9502e-02])

# %%
# normalised dataset ,and test and train dataloaders
iemocap_dataset_norm  = IEMOCAP_audio(mean=mean,std=std)
# initilizing the train and test datasets using the stored test and train indices
train_dataset_norm = torch.utils.data.Subset(iemocap_dataset_norm, train_indices)
test_dataset_norm = torch.utils.data.Subset(iemocap_dataset_norm, test_indices)

# %%
batch_size = 32

# data loaaders
train_loader_norm = DataLoader(dataset=train_dataset_norm, batch_size=batch_size, shuffle=True, collate_fn=custom_collate_fn)
test_loader_norm = DataLoader(dataset=test_dataset_norm, batch_size=batch_size, shuffle=False, collate_fn=custom_collate_fn)

# %% [markdown]
# ### **Acoustic only classifiers:**

# %%
test_loader_norm
train_loader_norm

# %%
# Set up the training settings
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Initialize the hyperparameters
learning_rate = 1e-4 
input_dim = 65 # iemocap_dataset[0][0].shape[-1] #  = 65 (the number of frame level features)
hidden_dim = 128
num_layers = 2
num_classes = len(np.unique(iemocap_dataset.y))
attention_dim = 64
# Out:
# cuda

# %%
# Initialize the model, loss function, and optimizer

# choose a model
# model_acoustic,model_name = BLSTM_lastblock(input_dim, hidden_dim,num_layers, num_classes).to(device), 'model_acoustic_I'
# model_acoustic,model_name = BLSTM_avg_pooling(input_dim, hidden_dim,num_layers, num_classes).to(device), 'model_acoustic_II'
model_acoustic,model_name  = BLSTMWithContextBasedAttention(input_dim, hidden_dim,num_layers, attention_dim, num_classes).to(device), 'model_acoustic_III'
print(model_acoustic)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_acoustic.parameters(), lr=learning_rate)
# Out:
# BLSTMWithContextBasedAttention(
#   (rnn): LSTM(65, 128, num_layers=2, batch_first=True, bidirectional=True)
#   (attention): ContextBasedAttention(
#     (wh): Linear(in_features=256, out_features=64, bias=True)
#     (tanh): Tanh()
#     (softmax): Softmax(dim=1)
#   )
#   (fc): Linear(in_features=256, out_features=4, bias=True)
# )

# %%
save_path = os.path.join(main_dir,'model_acoustic')
print(save_path)
# Out:
# /content/drive/MyDrive/IITB_EE/CS772_project/model_acoustic

# %%
num_epochs = 15
model_ = model_acoustic

from tqdm.notebook import tqdm
from sklearn.metrics import accuracy_score,balanced_accuracy_score
from collections import defaultdict

# Define a function to compute class-wise accuracy
def class_wise_accuracy(true_labels, predicted_labels, num_classes):
    class_correct = [0] * num_classes
    class_total = [0] * num_classes
    
    for t, p in zip(true_labels, predicted_labels):
        class_correct[t] += (t == p)
        class_total[t] += 1
        
    return [correct / total if total > 0 else 0 for correct, total in zip(class_correct, class_total)]

# Training loop
for epoch in range(num_epochs):
    model_.train() # <---------------
    train_loss = 0
    train_iter = 0
    train_labels = []
    train_preds = []
    
    loop = tqdm(enumerate(train_loader_norm), total=len(train_loader_norm), leave=True)
    for i, (features, labels, seq_lengths) in loop:
        features = features.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model_(features,seq_lengths) #<----------------
        loss = criterion(outputs, labels)
        train_loss += loss.item()
        train_iter += 1

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Update progress bar
        loop.set_description(f"Epoch [{epoch + 1}/{num_epochs}]")
        loop.set_postfix(loss=loss.item())

        # Store labels and predictions for training accuracy
        _, predicted = torch.max(outputs.data, 1)
        train_labels.extend(labels.cpu().numpy())
        train_preds.extend(predicted.cpu().numpy())

    # Evaluate the model on the test set
    model_.eval()
    test_loss = 0
    test_iter = 0
    test_labels = []
    test_preds = []
    
    with torch.no_grad():
        for features, labels, seq_lengths in test_loader_norm:
            features = features.to(device)
            labels = labels.to(device)

            outputs = model_(features,seq_lengths) #<----------------------
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            test_iter += 1
            
            _, predicted = torch.max(outputs.data, 1)
            test_labels.extend(labels.cpu().numpy())
            test_preds.extend(predicted.cpu().numpy())

    avg_train_loss = train_loss / train_iter
    avg_test_loss = test_loss / test_iter
    weighted_train_accuracy = accuracy_score(train_labels, train_preds)
    unweighted_train_accuracy = balanced_accuracy_score(train_labels, train_preds)
    weighted_test_accuracy = accuracy_score(test_labels, test_preds)
    unweighted_test_accuracy = balanced_accuracy_score(test_labels, test_preds)
    train_class_accuracies = class_wise_accuracy(train_labels, train_preds, num_classes)
    test_class_accuracies = class_wise_accuracy(test_labels, test_preds, num_classes)

    print(f"Epoch[{epoch + 1}] Avg Train Loss: {avg_train_loss:.4f}, Weighted Train Accuracy: {100 * weighted_train_accuracy:.2f}%, Unweighted Train Accuracy: {100 * unweighted_train_accuracy:.2f}%")
    print(f" Avg Test Loss: {avg_test_loss:.4f}, Weighted Test Accuracy: {100 * weighted_test_accuracy:.2f}%, Unweighted Test Accuracy: {100 * unweighted_test_accuracy:.2f}%")
    print(f"Train Class Accuracies: {', '.join([f'Class {i}: {100 * acc:.2f}%' for i, acc in enumerate(train_class_accuracies)])}")
    print(f"Test Class Accuracies: {', '.join([f'Class {i}: {100 * acc:.2f}%' for i, acc in enumerate(test_class_accuracies)])}")
    # Save the model checkpoint
    if epoch >= 5:
        file_path_epoch = os.path.join(save_path, model_name + str(epoch+1)+'.pth')
        torch.save(model_, file_path_epoch)
# Out:
#   0%|          | 0/138 [00:00<?, ?it/s]
# Epoch[1] Avg Train Loss: 1.2331, Weighted Train Accuracy: 43.32%, Unweighted Train Accuracy: 45.30%
#  Avg Test Loss: 1.0763, Weighted Test Accuracy: 50.91%, Unweighted Test Accuracy: 51.56%
# Train Class Accuracies: Class 0: 44.77%, Class 1: 55.38%, Class 2: 16.42%, Class 3: 64.63%
# Test Class Accuracies: Class 0: 44.39%, Class 1: 45.62%, Class 2: 52.28%, Class 3: 63.96%
#   0%|          | 0/138 [00:00<?, ?it/s]
# Epoch[2] Avg Train Loss: 1.0534, Weighted Train Accuracy: 52.31%, Unweighted Train Accuracy: 53.18%
#  Avg Test Loss: 1.0525, Weighted Test Accuracy: 51.81%, Unweighted Test Accuracy: 54.02%
# Train Class Accuracies: Class 0: 49.16%, Class 1: 39.13%, Class 2: 58.10%, Class 3: 66.33%
# Test Class Accuracies: Class 0: 43.93%, Class 1: 38.44%, Class 2: 52.01%, Class 3: 81.73%
#   0%|          | 0/138 [00:00<?, ?it/s]
# Epoch[3] Avg Train Loss: 1.0152, Weighted Train Accuracy: 54.64%, Unweighted Train Accuracy: 55.63%
#  Avg Test Loss: 1.0128, Weighted Test Accuracy: 56.16%, Unweighted Test Accuracy: 55.89%
# Train Class Accuracies: Class 0: 52.53%, Class 1: 40.73%, Class 2: 60.19%, Class 3: 69.05%
# Test Class Accuracies: Class 0: 48.13%, Class 1: 53.44%, Class 2: 60.05%, Class 3: 61.93%
#   0%|          | 0/138 [00:00<?, ?it/s]
# Epoch[4] Avg Train Loss: 0.9853, Weighted Train Accuracy: 56.97%, Unweighted Train Accuracy: 57.97%
#  Avg Test Loss: 1.0023, Weighted Test Accuracy: 55.16%, Unweighted Test Accuracy: 55.51%
# Train Class Accuracies: Class 0: 56.02%, Class 1: 44.55%, Class 2: 61.02%, Class 3: 70.29%
# Test Class Accuracies: Class 0: 42.06%, Class 1: 54.69%, Class 2: 55.23%, Class 3: 70.05%
#   0%|          | 0/138 [00:00<?, ?it/s]
# Epoch[5] Avg Train Loss: 0.9543, Weighted Train Accuracy: 58.61%, Unweighted Train Accuracy: 59.60%
#  Avg Test Loss: 0.9863, Weighted Test Accuracy: 56.07%, Unweighted Test Accuracy: 57.89%
# Train Class Accuracies: Class 0: 59.06%, Class 1: 47.22%, Class 2: 61.62%, Class 3: 70.52%
# Test Class Accuracies: Class 0: 49.07%, Class 1: 53.12%, Class 2: 50.67%, Class 3: 78.68%
#   0%|          | 0/138 [00:00<?, ?it/s]
# Epoch[6] Avg Train Loss: 0.9255, Weighted Train Accuracy: 60.21%, Unweighted Train Accuracy: 61.17%
#  Avg Test Loss: 0.9717, Weighted Test Accuracy: 57.34%, Unweighted Test Accuracy: 59.55%
# Train Class Accuracies: Class 0: 61.87%, Class 1: 50.42%, Class 2: 61.99%, Class 3: 70.41%
# Test Class Accuracies: Class 0: 62.15%, Class 1: 44.38%, Class 2: 56.03%, Class 3: 75.63%
#   0%|          | 0/138 [00:00<?, ?it/s]
# Epoch[7] Avg Train Loss: 0.9016, Weighted Train Accuracy: 61.98%, Unweighted Train Accuracy: 63.20%
#  Avg Test Loss: 0.9701, Weighted Test Accuracy: 58.88%, Unweighted Test Accuracy: 59.64%
# Train Class Accuracies: Class 0: 65.80%, Class 1: 52.33%, Class 2: 61.54%, Class 3: 73.13%
# Test Class Accuracies: Class 0: 59.81%, Class 1: 52.19%, Class 2: 60.05%, Class 3: 66.50%
#   0%|          | 0/138 [00:00<?, ?it/s]
# Epoch[8] Avg Train Loss: 0.8646, Weighted Train Accuracy: 64.27%, Unweighted Train Accuracy: 65.41%
#  Avg Test Loss: 0.9668, Weighted Test Accuracy: 59.06%, Unweighted Test Accuracy: 59.10%
# Train Class Accuracies: Class 0: 68.95%, Class 1: 54.39%, Class 2: 64.62%, Class 3: 73.70%
# Test Class Accuracies: Class 0: 46.26%, Class 1: 53.75%, Class 2: 63.81%, Class 3: 72.59%
#   0%|          | 0/138 [00:00<?, ?it/s]
# Epoch[9] Avg Train Loss: 0.8352, Weighted Train Accuracy: 65.31%, Unweighted Train Accuracy: 66.54%
#  Avg Test Loss: 0.9590, Weighted Test Accuracy: 60.05%, Unweighted Test Accuracy: 60.89%
# Train Class Accuracies: Class 0: 70.75%, Class 1: 57.51%, Class 2: 62.97%, Class 3: 74.94%
# Test Class Accuracies: Class 0: 61.21%, Class 1: 46.88%, Class 2: 65.42%, Class 3: 70.05%
#   0%|          | 0/138 [00:00<?, ?it/s]
# Epoch[10] Avg Train Loss: 0.8016, Weighted Train Accuracy: 67.46%, Unweighted Train Accuracy: 68.73%
#  Avg Test Loss: 0.9651, Weighted Test Accuracy: 60.51%, Unweighted Test Accuracy: 59.59%
# Train Class Accuracies: Class 0: 73.00%, Class 1: 58.43%, Class 2: 66.04%, Class 3: 77.44%
# Test Class Accuracies: Class 0: 59.81%, Class 1: 50.62%, Class 2: 71.58%, Class 3: 56.35%
#   0%|          | 0/138 [00:00<?, ?it/s]
# Epoch[11] Avg Train Loss: 0.7670, Weighted Train Accuracy: 68.91%, Unweighted Train Accuracy: 70.20%
#  Avg Test Loss: 0.9890, Weighted Test Accuracy: 60.05%, Unweighted Test Accuracy: 60.80%
# Train Class Accuracies: Class 0: 76.15%, Class 1: 59.88%, Class 2: 67.32%, Class 3: 77.44%
# Test Class Accuracies: Class 0: 56.07%, Class 1: 59.69%, Class 2: 57.37%, Class 3: 70.05%
#   0%|          | 0/138 [00:00<?, ?it/s]
# Epoch[12] Avg Train Loss: 0.7348, Weighted Train Accuracy: 70.61%, Unweighted Train Accuracy: 71.79%
#  Avg Test Loss: 0.9966, Weighted Test Accuracy: 60.05%, Unweighted Test Accuracy: 62.00%
# Train Class Accuracies: Class 0: 77.84%, Class 1: 62.17%, Class 2: 69.27%, Class 3: 77.89%
# Test Class Accuracies: Class 0: 62.62%, Class 1: 53.75%, Class 2: 55.50%, Class 3: 76.14%
#   0%|          | 0/138 [00:00<?, ?it/s]
# Epoch[13] Avg Train Loss: 0.6957, Weighted Train Accuracy: 72.40%, Unweighted Train Accuracy: 73.64%
#  Avg Test Loss: 1.0274, Weighted Test Accuracy: 58.97%, Unweighted Test Accuracy: 61.07%
# Train Class Accuracies: Class 0: 80.31%, Class 1: 64.38%, Class 2: 70.16%, Class 3: 79.71%
# Test Class Accuracies: Class 0: 62.15%, Class 1: 51.56%, Class 2: 54.42%, Class 3: 76.14%
#   0%|          | 0/138 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-6bc72e0d5a8e> in <cell line: 20>()
#      31
#      32         # Forward pass
# ---> 33         outputs = model_(features,seq_lengths) #<----------------
#      34         loss = criterion(outputs, labels)
#      35         train_loss += loss.item()
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-12-febfb34dbcde> in forward(self, x, lengths)
#      26         x = torch.nn.utils.rnn.pack_padded_sequence(x, lengths, batch_first=True, enforce_sorted=False)
#      27         # Pass the packed sequence through the LSTM
# ---> 28         x, _ = self.rnn(x)
#      29         # Unpack the packed sequence
#      30         x, _ = torch.nn.utils.rnn.pad_packed_sequence(x, batch_first=True)
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     813                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     814         else:
# --> 815             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     816                               self.num_layers, self.dropout, self.training, self.bidirectional)
#     817         output = result[0]
#
# KeyboardInterrupt:

# %%
# Define the file path for saving the model
file_path_epoch = os.path.join(save_path, model_name + str(epoch+1)+'.pth')
# Save the model state dictionary to a file
torch.save(model_, file_path_epoch)

# %% [markdown]
# ### Results for Acoustic only models:
# **Train Results:**
#
# | Model | Train Loss | Weighted Accuracy | Unweighted Accuracy | Angry Acc. | Happy Acc. | Neutral Acc. | Sad Acc. |
# |-------|-----------|------------------|---------------------|------------|------------|--------------|----------|
# | Last Block (epochs=15) | 1.1084 | 49.95% | 51.57% | 52.19% | 37.83% | 48.80% | 67.46% |
# | Avg. Pool (epochs15) | 0.9579 | 61.41% | 62.69% | 65.69% | 51.56% | 60.72% | 72.79% |
# | Attention based (attention layer size - 64) (e=14) | 0.8352 | 65.31% | 66.54% | 70.75% | 57.51% | 62.97% | 74.94% |
#
#
# **Test Results:**
#
# | Model | Test Loss | Weighted Accuracy | Unweighted Accuracy | Angry Acc. | Happy Acc. | Neutral Acc. | Sad Acc. |
# |-------|-----------|------------------|---------------------|------------|------------|--------------|----------|
# | Last Block (e=15) | 1.1296 | 49.82% | 50.03% | 38.79% | 38.44% | 57.91% | 64.97% |
# | Avg. Pool (e=15) | 1.0815 | 54.98% | 54.45% | 37.38% | 49.38% | 63.00% | 68.02% |
# | Attention based (attention layer size - 64) (e=9) | 0.959 | 60.05% | 60.89% | 61.21% | 46.88% | 65.42% | 70.05% |
#
# Note: The categorical names used are: Angry, Happy, Neutral, and Sad.

# %% [markdown]
# 3. (32/9)*** Avg Train Loss: 0.8352, Weighted Train Accuracy: 65.31%, Unweighted Train Accuracy: 66.54%
#  Avg Test Loss: 0.9590, Weighted Test Accuracy: 60.05%, Unweighted Test Accuracy: 60.89%
# Train Class Accuracies: Class 0: 70.75%, Class 1: 57.51%, Class 2: 62.97%, Class 3: 74.94%
# Test Class Accuracies: Class 0: 61.21%, Class 1: 46.88%, Class 2: 65.42%, Class 3: 70.05%
#
# 1. (64)Avg Train Loss: 0.8493, Weighted Train Accuracy: 64.92%, Unweighted Train Accuracy: 66.16%
#  Avg Test Loss: 0.9746, Weighted Test Accuracy: 57.34%, Unweighted Test Accuracy: 59.20%
# Train Class Accuracies: Class 0: 69.52%, Class 1: 54.39%, Class 2: 65.22%, Class 3: 75.51%
# Test Class Accuracies: Class 0: 59.35%, Class 1: 44.69%, Class 2: 57.64%, Class 3: 75.13%
#
# 2. (128/14) Avg Train Loss: 0.8812, Weighted Train Accuracy: 63.36%, Unweighted Train Accuracy: 64.49%
#  Avg Test Loss: 0.9619, Weighted Test Accuracy: 58.88%, Unweighted Test Accuracy: 60.11%
# Train Class Accuracies: Class 0: 66.37%, Class 1: 53.55%, Class 2: 63.79%, Class 3: 74.26%
# Test Class Accuracies: Class 0: 54.67%, Class 1: 50.62%, Class 2: 59.52%, Class 3: 75.63%
#
#
#
# ***saved

# %% [markdown]
# # **lexical Only Model**

# %%
# !pip install transformers
# !pip install contractions
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 62.0 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 105.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.28.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 7.5 MB/s eta 0:00:00
# Collecting pyahocorasick
#   Downloading pyahocorasick-2.0.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 16.2 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.0.0 textsearch-0.0.24

# %%
from transformers import BertTokenizer, BertModel
import contractions

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = BertModel.from_pretrained('bert-base-uncased')
tokenizer.add_special_tokens({'additional_special_tokens': ['<sil>', '++laughter++', '++breathing++']}) # Modify the tokenizer to add special tokens
bert_model.resize_token_embeddings(len(tokenizer))  # Update the BERT model to account for the new tokens
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Embedding(30525, 768)

# %% [markdown]
# To retain the <sil> (silence) token's information, we can map it to a special token in BERT's vocabulary. The idea is to replace the <sil> token with a token that exists in BERT's vocabulary but doesn't appear in regular text, like [unused0].
#
# It should be noted that the [unused0] token may not have a meaningful representation in BERT's pre-trained embeddings. But fine-tuning BERT on your specific dataset might help the model learn a more meaningful representation for the silence token in the context of your task.

# %% [markdown]
# To expand contractions like "That's" to "That is" before feeding the text into BERT, you can use a library like contractions or write a custom function to handle specific contractions. Here's how to use the contractions library

# %% [markdown]
# ++LAUGHTER++,++GARBAGE++,++BREATHING++ total 172 instance in total
# 1. remove garbage
# 2. keep laugh and breath

# %%
trans_words = data['trans_words'].copy()

# %%
#  remove the <s>, </s>  tokens from the text before tokenizing 
def preprocess_text(text,tokenizer):
    text = text.lower()
    text = contractions.fix(text)  # Expand contractions

    # note: since we have lowered the case, we are using garbage instead of GARBAGE 
    text = text.replace('<s>', '[CLS]').replace('</s>', '[SEP]').replace('++garbage++', '') #.replace('++breathing++', '').replace('++laughter++', '').replace('<sil>', '')
    # print(text)
    tokens = tokenizer.tokenize(text)
    # print(tokens)
    input_ids = tokenizer.convert_tokens_to_ids(tokens)
    return input_ids

# %%
idx = 2
trans_word = trans_words.iloc[idx]
lst = trans_word.split()
print(len(lst),lst)
print('transcribed words:',trans_word)
tokenised = preprocess_text(trans_words.iloc[idx],tokenizer)
print('transcribed words:',tokenised,len(tokenised))
input_ids = torch.tensor(tokenised).unsqueeze(0)
outputs = bert_model(input_ids)
print(outputs.last_hidden_state.squeeze(0))
# Out:
# 11 ['<s>', 'YOU', 'KEEP', 'SAYING', 'MY', 'FLASHLIGHT', 'LIKE', "IT'S", 'JUST', 'YOURS', '</s>']
# transcribed words: <s> YOU KEEP SAYING MY FLASHLIGHT LIKE IT'S JUST YOURS </s>
# [CLS] you keep saying my flashlight like it is just yours [SEP]
# ['[CLS]', 'you', 'keep', 'saying', 'my', 'flashlight', 'like', 'it', 'is', 'just', 'yours', '[SEP]']
# transcribed words: [101, 2017, 2562, 3038, 2026, 15257, 2066, 2009, 2003, 2074, 6737, 102] 12
# tensor([[ 0.4242,  0.3604, -0.0238,  ..., -0.3269,  0.2944,  0.4648],
#         [ 0.5419,  0.2180,  0.0233,  ...,  0.2271,  1.1444,  0.3384],
#         [ 0.7502,  0.1607,  0.7397,  ..., -0.4460, -0.0597,  0.5583],
#         ...,
#         [ 0.4529,  0.0954,  0.9105,  ...,  0.2409, -0.0369,  1.0204],
#         [ 0.1697,  0.0588,  0.1713,  ...,  0.3682,  0.0328,  0.5527],
#         [ 0.9737,  0.4401, -0.0175,  ...,  0.0230, -0.3806, -0.4799]],
#        grad_fn=<SqueezeBackward1>)

# %%
idx = 2
trans_word = trans_words.iloc[idx]
lst = trans_word.split()
print(len(lst),lst)
print('transcribed words:',trans_word)
tokenised = preprocess_text(trans_words.iloc[idx],tokenizer)[1:]
print('transcribed words:',tokenised,len(tokenised))
input_ids = torch.tensor(tokenised).unsqueeze(0)
outputs = bert_model(input_ids)
print(outputs.last_hidden_state.squeeze(0))
# Out:
# 11 ['<s>', 'YOU', 'KEEP', 'SAYING', 'MY', 'FLASHLIGHT', 'LIKE', "IT'S", 'JUST', 'YOURS', '</s>']
# transcribed words: <s> YOU KEEP SAYING MY FLASHLIGHT LIKE IT'S JUST YOURS </s>
# [CLS] you keep saying my flashlight like it is just yours [SEP]
# ['[CLS]', 'you', 'keep', 'saying', 'my', 'flashlight', 'like', 'it', 'is', 'just', 'yours', '[SEP]']
# transcribed words: [2017, 2562, 3038, 2026, 15257, 2066, 2009, 2003, 2074, 6737, 102] 11
# tensor([[ 0.2970,  0.2857,  0.0788,  ...,  0.0213, -0.0377,  0.1018],
#         [ 0.7928,  0.5266,  1.0389,  ...,  0.2718, -0.2735,  0.2367],
#         [ 0.6917,  0.5986,  0.3120,  ...,  0.0748,  0.0761,  0.2420],
#         ...,
#         [ 0.3667, -0.1594,  0.6207,  ...,  0.6107, -0.0207,  0.6009],
#         [-0.2820, -0.3096, -0.0326,  ...,  0.9092,  0.0034,  0.0447],
#         [ 1.2007,  0.4542,  0.0052,  ...,  0.0946, -0.6579, -0.3773]],
#        grad_fn=<SqueezeBackward1>)

# %% [markdown]
# ### Lexical Dataset Class

# %%
class IEMOCAP_lexical(Dataset):
    def __init__(self, data, tokenizer, bert_model, max_len=512):
        data = pd.read_pickle(data_pickel_path)
        self.data = data['trans_words']
        y = data['emotion'].values
        self.label_encoder = LabelEncoder()
        # self.spk = data['spk'] 
        self.y = self.label_encoder.fit_transform(y)
        self.tokenizer = tokenizer
        self.bert_model = bert_model
        self.max_len = max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        text = self.data[idx]
        input_ids = preprocess_text(text,self.tokenizer)
        seq_size = len(input_ids)
        input_ids = self.truncate(input_ids)
        # attention_mask = self.create_attention_mask(input_ids)
        embeddings = self.extract_embeddings(input_ids)#, attention_mask)
        return torch.tensor(embeddings),torch.tensor(self.y[idx]), seq_size

    def truncate(self, sequence):
        if len(sequence) > self.max_len:
            return sequence[:self.max_len]
        else:
            return sequence # + [0] * (self.max_len - len(sequence))

    def create_attention_mask(self, input_ids):
        return [1 if token_id > 0 else 0 for token_id in input_ids]

    def extract_embeddings(self, input_ids):#, attention_mask):
        with torch.no_grad():
            input_ids = torch.tensor(input_ids).unsqueeze(0)
            # attention_mask = torch.tensor(attention_mask).unsqueeze(0)
            outputs = self.bert_model(input_ids)#, attention_mask=attention_mask)
            embeddings = outputs.last_hidden_state.squeeze(0).numpy()
        return embeddings

# %%
dataset_lex = IEMOCAP_lexical(data, tokenizer, bert_model)
feat = dataset_lex[0]
print(feat[0].shape,feat)
# Out:
# torch.Size([4, 768]) (tensor([[-7.6917e-02,  3.0443e-01, -3.8888e-02,  ..., -3.1553e-02,
#           6.7862e-02,  3.1871e-01],
#         [ 1.5550e+00, -3.1333e-01,  2.5032e-01,  ..., -2.2655e-01,
#           2.3212e-01,  9.8409e-02],
#         [ 5.7058e-02, -3.9955e-01, -1.1912e-01,  ...,  5.8026e-01,
#           3.8527e-01, -7.7418e-02],
#         [ 8.8470e-01, -3.3663e-05, -2.3655e-01,  ...,  1.8076e-01,
#          -6.3129e-01, -1.5363e-01]]), tensor(2), 4)

# %% [markdown]
# **Custom Collate Function**

# %%
def custom_collate_fn(batch):
    features, labels,seq_lengths = zip(*batch)
    # seq_lengths = [len(seq) for seq in features]

    # Sort sequences by length in descending order
    seq_lengths, perm_idx = torch.tensor(seq_lengths).sort(0, descending=True)
    features = [features[i] for i in perm_idx]
    labels = torch.tensor([labels[i] for i in perm_idx])

    # Pad the sequences
    padded_features = pad_sequence(features, batch_first=True)
    return padded_features, labels, seq_lengths

# %% [markdown]
# **Randomly splitting the dataset and storing the test (20%) and train (80%) indices**

# %%
num_samp = len(dataset_lex)
train_size = int(0.8 * len(dataset_lex))
test_size = len(dataset_lex) - train_size
train_indices = random.sample(range(num_samp), train_size)
test_indices = [i for i in range(num_samp) if i not in train_indices ]
print("train_indices",train_indices)
print("test_indices",test_indices)
# Out:
# train_indices [5238, 912, 204, 2253, 2006, 1828, 1143, 839, 4467, 712, 4837, 3456, 260, 244, 767, 1791, 1905, 4139, 4931, 217, 4597, 1628, 5323, 4464, 3436, 1805, 3679, 4827, 2278, 53, 1307, 3462, 2787, 2276, 1273, 1763, 2757, 837, 759, 3112, 792, 2940, 2817, 4945, 2166, 355, 3763, 4392, 1022, 3100, 645, 4522, 2401, 5149, 5066, 2962, 4729, 1575, 569, 375, 5417, 1866, 2370, 653, 1907, 827, 3113, 2277, 3714, 5207, 2988, 1332, 3032, 2910, 1716, 2187, 5308, 584, 4990, 5201, 1401, 4375, 2005, 1338, 3786, 3108, 2211, 5242, 4562, 1799, 2656, 458, 1876, 262, 2584, 3286, 2193, 542, 1728, 4646, 2577, 1741, 5369, 4089, 3241, 5266, 3758, 1170, 2169, 5513, 2020, 4598, 4415, 2152, 4788, 3509, 4780, 3271, 2965, 1796, 1133, 4174, 4042, 744, 385, 898, 1252, 5140, 1310, 3458, 4885, 520, 3152, 3126, 4881, 3834, 4334, 2059, 4532, 94, 938, 4398, 2185, 5250, 2786, 913, 2404, 3561, 1295, 3716, 26, 2157, 4100, 1463, 4158, 871, 5122, 2444, 5234, 5365, 4988, 1629, 5393, 3063, 1323, 4418, 4344, 4, 4906, 2655, 4002, 159, 916, 2973, 2519, 1961, 474, 1973, 4647, 5469, 701, 3981, 566, 4363, 1030, 1051, 3893, 4503, 1352, 2171, 4322, 4969, 3466, 1735, 4417, 1647, 2553, 3268, 3059, 3588, 4239, 3698, 991, 2030, 1840, 524, 2769, 172, 4819, 4537, 1885, 4820, 1804, 58, 581, 5169, 482, 1875, 552, 257, 2706, 580, 4211, 1949, 2281, 3976, 1755, 5325, 1083, 4677, 4720, 3872, 1990, 3874, 3334, 1559, 772, 794, 3531, 2902, 3469, 3367, 3825, 443, 806, 496, 3298, 2779, 895, 2036, 1569, 1558, 4393, 3675, 1148, 5508, 1503, 5295, 3789, 2046, 617, 3630, 4508, 802, 414, 4428, 120, 764, 1936, 1362, 3329, 3978, 3943, 1751, 3285, 480, 1348, 3104, 17, 3198, 2172, 3727, 2336, 3465, 4552, 3986, 1268, 1555, 2430, 1783, 479, 4744, 4441, 499, 2569, 468, 410, 4785, 3905, 4119, 4350, 1289, 465, 4160, 656, 1522, 561, 4874, 556, 1926, 3307, 982, 4666, 2016, 4742, 4870, 325, 5073, 671, 3434, 4781, 4630, 4282, 2591, 2136, 1673, 2573, 1955, 2175, 3242, 1072, 2457, 3745, 2590, 594, 76, 3754, 5088, 4612, 819, 600, 4404, 1746, 4144, 5239, 1085, 2859, 563, 2001, 3027, 2334, 1292, 3589, 4450, 2478, 5010, 4333, 64, 4543, 2452, 848, 1100, 5475, 945, 876, 5381, 5485, 2231, 2308, 4954, 1725, 2808, 1667, 2162, 4140, 5349, 2057, 416, 756, 5279, 2266, 361, 29, 2732, 1071, 2145, 5355, 3619, 4519, 3503, 4594, 79, 5347, 616, 1221, 4469, 295, 3024, 4771, 4526, 1213, 3520, 1044, 342, 2525, 2987, 326, 2931, 1720, 2044, 842, 2897, 4586, 5249, 5084, 1266, 1939, 1331, 1450, 3377, 203, 1469, 2721, 3372, 2032, 5377, 1304, 885, 3133, 317, 3855, 1822, 1634, 3770, 2864, 2500, 1864, 1826, 193, 1582, 3264, 2689, 2282, 568, 2286, 2876, 4173, 3274, 5472, 2712, 226, 944, 2139, 1462, 4756, 2174, 313, 888, 4887, 3559, 2831, 5225, 3574, 4966, 4189, 947, 3155, 4723, 1557, 2086, 363, 3572, 13, 4259, 4410, 1614, 2983, 3533, 573, 2704, 2571, 1020, 2460, 4154, 2533, 3345, 2672, 3296, 2422, 4541, 1042, 1571, 3444, 3105, 1425, 4662, 2465, 3326, 4488, 3, 2489, 2350, 1721, 3521, 4751, 5328, 2639, 3809, 5132, 3622, 1750, 4187, 3876, 1390, 694, 2324, 4222, 2745, 765, 1924, 2542, 5315, 1631, 1207, 200, 378, 5437, 3892, 596, 3730, 3395, 4715, 1592, 3145, 4049, 3273, 1998, 1208, 45, 873, 3482, 1792, 1440, 4243, 3805, 411, 4566, 2041, 994, 3739, 1092, 3806, 4351, 4578, 4877, 2599, 3625, 4135, 3495, 5021, 3652, 1303, 3888, 3686, 2123, 2025, 2271, 4270, 3969, 1959, 2249, 3603, 634, 2340, 1920, 2225, 2751, 2619, 4424, 660, 5399, 1235, 1894, 3137, 1251, 1752, 526, 3398, 3339, 2710, 4445, 3816, 3406, 510, 1694, 3441, 3190, 4784, 160, 4716, 3116, 3907, 48, 2881, 2446, 3194, 3432, 4409, 4473, 1806, 3999, 1797, 2235, 3570, 5248, 237, 3185, 2753, 3312, 5331, 3828, 1045, 5438, 220, 3227, 4848, 4623, 222, 687, 3511, 1111, 3782, 1488, 4974, 2131, 5026, 2681, 1733, 3724, 2677, 2764, 4884, 2279, 3453, 2066, 670, 3852, 158, 5354, 426, 2866, 1836, 562, 329, 254, 5150, 1633, 166, 1248, 1954, 1034, 3879, 937, 4620, 1785, 5012, 2099, 3021, 1374, 5379, 1341, 2548, 5092, 4740, 210, 2555, 4920, 3074, 3249, 1624, 622, 1989, 834, 2470, 5317, 4636, 336, 2844, 4364, 5 ...
# test_indices [0, 8, 11, 20, 22, 28, 30, 31, 32, 35, 36, 42, 47, 51, 54, 55, 61, 65, 69, 73, 75, 78, 80, 81, 84, 85, 86, 88, 95, 96, 97, 99, 102, 104, 105, 108, 117, 123, 128, 136, 139, 140, 143, 144, 146, 147, 155, 162, 165, 177, 180, 189, 191, 194, 197, 202, 224, 225, 228, 232, 238, 239, 264, 266, 271, 272, 274, 284, 285, 287, 289, 292, 293, 296, 297, 305, 310, 312, 320, 331, 339, 358, 362, 364, 377, 379, 380, 386, 391, 392, 393, 395, 397, 402, 406, 409, 417, 427, 431, 435, 437, 441, 442, 445, 451, 456, 460, 469, 470, 472, 473, 481, 483, 489, 490, 494, 505, 506, 514, 515, 518, 537, 558, 587, 589, 592, 593, 595, 607, 608, 619, 621, 630, 638, 639, 640, 641, 642, 648, 666, 675, 676, 680, 696, 703, 708, 711, 715, 722, 723, 725, 729, 741, 742, 743, 752, 757, 758, 769, 773, 776, 779, 785, 788, 798, 805, 809, 824, 829, 830, 831, 836, 850, 851, 854, 860, 862, 866, 868, 869, 870, 880, 882, 896, 899, 901, 902, 910, 911, 915, 917, 922, 930, 933, 936, 939, 956, 957, 960, 961, 989, 995, 998, 1011, 1017, 1019, 1027, 1029, 1039, 1040, 1041, 1043, 1049, 1052, 1060, 1061, 1062, 1063, 1067, 1069, 1075, 1080, 1081, 1086, 1088, 1089, 1090, 1091, 1102, 1103, 1105, 1107, 1116, 1121, 1123, 1128, 1131, 1136, 1144, 1146, 1147, 1156, 1157, 1166, 1168, 1177, 1181, 1187, 1190, 1191, 1194, 1202, 1205, 1214, 1223, 1224, 1226, 1234, 1239, 1244, 1249, 1254, 1258, 1259, 1272, 1278, 1279, 1293, 1300, 1301, 1312, 1318, 1324, 1326, 1327, 1337, 1339, 1344, 1357, 1366, 1367, 1369, 1375, 1376, 1381, 1384, 1389, 1391, 1396, 1400, 1403, 1404, 1408, 1415, 1422, 1433, 1446, 1452, 1455, 1461, 1466, 1487, 1493, 1512, 1513, 1515, 1521, 1524, 1526, 1534, 1548, 1549, 1551, 1552, 1560, 1578, 1587, 1596, 1598, 1611, 1612, 1615, 1617, 1618, 1619, 1622, 1639, 1645, 1648, 1649, 1655, 1658, 1662, 1665, 1668, 1676, 1678, 1688, 1698, 1707, 1726, 1727, 1739, 1740, 1747, 1748, 1754, 1771, 1774, 1775, 1776, 1778, 1782, 1786, 1787, 1816, 1817, 1830, 1832, 1833, 1849, 1854, 1855, 1856, 1858, 1859, 1860, 1868, 1881, 1883, 1897, 1898, 1900, 1901, 1911, 1916, 1919, 1930, 1932, 1937, 1938, 1941, 1946, 1957, 1969, 1970, 1971, 1976, 1981, 1988, 1992, 1994, 2007, 2008, 2012, 2013, 2022, 2031, 2034, 2035, 2050, 2061, 2064, 2069, 2072, 2073, 2081, 2089, 2094, 2095, 2103, 2104, 2106, 2114, 2115, 2117, 2118, 2128, 2130, 2133, 2138, 2140, 2142, 2150, 2155, 2158, 2159, 2177, 2181, 2182, 2196, 2204, 2205, 2209, 2213, 2217, 2218, 2222, 2223, 2244, 2245, 2264, 2267, 2273, 2274, 2275, 2292, 2294, 2299, 2313, 2327, 2328, 2332, 2338, 2352, 2353, 2357, 2363, 2367, 2373, 2374, 2375, 2381, 2382, 2391, 2394, 2396, 2397, 2400, 2402, 2416, 2419, 2421, 2428, 2436, 2455, 2458, 2459, 2463, 2466, 2471, 2480, 2482, 2486, 2492, 2494, 2495, 2503, 2505, 2507, 2509, 2522, 2523, 2527, 2529, 2532, 2534, 2543, 2544, 2554, 2562, 2563, 2566, 2570, 2578, 2585, 2600, 2609, 2614, 2621, 2623, 2653, 2658, 2659, 2666, 2673, 2678, 2682, 2692, 2693, 2695, 2699, 2702, 2703, 2705, 2708, 2713, 2714, 2716, 2725, 2729, 2733, 2738, 2739, 2740, 2748, 2763, 2772, 2775, 2797, 2798, 2799, 2801, 2806, 2815, 2823, 2832, 2846, 2847, 2852, 2853, 2857, 2871, 2874, 2877, 2879, 2884, 2885, 2888, 2891, 2894, 2900, 2904, 2909, 2911, 2916, 2923, 2929, 2933, 2935, 2937, 2945, 2957, 2959, 2966, 2968, 2974, 2980, 2984, 2986, 2989, 2993, 2998, 2999, 3016, 3020, 3022, 3029, 3030, 3037, 3038, 3040, 3042, 3045, 3046, 3057, 3064, 3067, 3068, 3075, 3076, 3082, 3086, 3089, 3093, 3094, 3095, 3098, 3106, 3107, 3109, 3118, 3122, 3132, 3136, 3139, 3143, 3147, 3156, 3163, 3164, 3170, 3171, 3173, 3177, 3178, 3182, 3184, 3186, 3192, 3196, 3203, 3205, 3208, 3209, 3215, 3217, 3218, 3219, 3220, 3226, 3234, 3236, 3238, 3254, 3258, 3267, 3269, 3272, 3275, 3277, 3278, 3279, 3284, 3293, 3294, 3295, 3301, 3305, 3314, 3315, 3320, 3322, 3333, 3337, 3340, 3341, 3347, 3348, 3351, 3352, 3355, 3356, 3357, 3359, 3360, 3364, 3369, 3371, 3373, 3391, 3393, 3402, 3410, 3413, 3417, 3422, 3424, 3425, 3431, 3435, 3445, 3446, 3447, 3449, 3452, 3454, 3459, 3461, 3468, 3472, 3477, 3480, 3491, ...

# %%
batch_size = 32

train_dataset_lex = torch.utils.data.Subset(dataset_lex, train_indices)
train_loader_lex = DataLoader(dataset=train_dataset_lex, batch_size=batch_size, shuffle=True,collate_fn=custom_collate_fn)

test_dataset_lex = torch.utils.data.Subset(dataset_lex, test_indices)
test_loader_lex = DataLoader(dataset=test_dataset_lex, batch_size=batch_size, shuffle=False,collate_fn=custom_collate_fn)

# %%
train_dataset_lex[0][0].shape
# Out:
# torch.Size([29, 768])

# %% [markdown]
# ## **BLSTM based Lexical only classifiers:**

# %% [markdown]
# ### Training and Testing the Audio only Model

# %%
dataset_lex[0][0].shape[-1]
# Out:
# 768

# %%
train_loader_lex
test_loader_lex

# %%
# Set up the training settings
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Initialize the hyperparameters
learning_rate = 1e-4 
input_dim = 768 # dataset_lex[0][0].shape[-1] #  = 768 (the size of the word embeddings)
hidden_dim = 128
num_layers = 2
num_classes = 4 # len(np.unique(dataset_lex.y))
attention_dim = 64
# Out:
# cuda

# %%
# Initialize the model, loss function, and optimizer

# choose a model
model_lex,model_name = BLSTM_lastblock(input_dim, hidden_dim,num_layers, num_classes).to(device), 'model_lex_I'
# model_lex,model_name = BLSTM_avg_pooling(input_dim, hidden_dim,num_layers, num_classes).to(device), 'model_lex_II'
# model_lex,model_name  = BLSTMWithContextBasedAttention(input_dim, hidden_dim,num_layers, attention_dim, num_classes).to(device), 'model_lex_III'
print(model_lex)

criterion = nn.CrossEntropyLoss()
weight_decay = 1e-5
optimizer = torch.optim.Adam(model_lex.parameters(), lr=learning_rate, weight_decay=weight_decay)
# Out:
# BLSTM_lastblock(
#   (rnn): LSTM(768, 128, num_layers=2, batch_first=True, bidirectional=True)
#   (fc): Linear(in_features=256, out_features=4, bias=True)
# )

# %%
save_path = os.path.join(main_dir,'model_lexical')

# %%
num_epochs = 10
model_ = model_lex

from tqdm.notebook import tqdm
from sklearn.metrics import accuracy_score,balanced_accuracy_score
from collections import defaultdict
from google.colab import files

# Define a function to compute class-wise accuracy
def class_wise_accuracy(true_labels, predicted_labels, num_classes):
    class_correct = [0] * num_classes
    class_total = [0] * num_classes
    
    for t, p in zip(true_labels, predicted_labels):
        class_correct[t] += (t == p)
        class_total[t] += 1
        
    return [correct / total if total > 0 else 0 for correct, total in zip(class_correct, class_total)]

# Training loop

for epoch in range(num_epochs):
    model_.train() # <---------------------------
    train_loss = 0
    train_iter = 0
    train_labels = []
    train_preds = []
    
    loop = tqdm(enumerate(train_loader_lex), total=len(train_loader_lex), leave=True)
    for i, (features, labels, seq_lengths) in loop:
        features = features.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model_(features,seq_lengths) # <-----------------
        loss = criterion(outputs, labels)
        train_loss += loss.item()
        train_iter += 1

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Update progress bar
        loop.set_description(f"Epoch [{epoch + 1}/{num_epochs}]")
        loop.set_postfix(loss=loss.item())

        # Store labels and predictions for training accuracy
        _, predicted = torch.max(outputs.data, 1)
        train_labels.extend(labels.cpu().numpy())
        train_preds.extend(predicted.cpu().numpy())

    # Evaluate the model on the test set
    model_.eval() # <-----------------------------
    test_loss = 0
    test_iter = 0
    test_labels = []
    test_preds = []
    
    with torch.no_grad():
        for features, labels, seq_lengths in test_loader_lex:
            features = features.to(device)
            labels = labels.to(device)

            outputs = model_(features,seq_lengths) #<------------------
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            test_iter += 1
            
            _, predicted = torch.max(outputs.data, 1)
            test_labels.extend(labels.cpu().numpy())
            test_preds.extend(predicted.cpu().numpy())

    avg_train_loss = train_loss / train_iter
    avg_test_loss = test_loss / test_iter
    weighted_train_accuracy = accuracy_score(train_labels, train_preds)
    unweighted_train_accuracy = balanced_accuracy_score(train_labels, train_preds)
    weighted_test_accuracy = accuracy_score(test_labels, test_preds)
    unweighted_test_accuracy = balanced_accuracy_score(test_labels, test_preds)
    train_class_accuracies = class_wise_accuracy(train_labels, train_preds, num_classes)
    test_class_accuracies = class_wise_accuracy(test_labels, test_preds, num_classes)

    print(f"Epoch[{epoch + 1}] Avg Train Loss: {avg_train_loss:.4f}, Weighted Train Accuracy: {100 * weighted_train_accuracy:.2f}%, Unweighted Train Accuracy: {100 * unweighted_train_accuracy:.2f}%")
    print(f" Avg Test Loss: {avg_test_loss:.4f}, Weighted Test Accuracy: {100 * weighted_test_accuracy:.2f}%, Unweighted Test Accuracy: {100 * unweighted_test_accuracy:.2f}%")
    print(f"Train Class Accuracies: {', '.join([f'Class {i}: {100 * acc:.2f}%' for i, acc in enumerate(train_class_accuracies)])}")
    print(f"Test Class Accuracies: {', '.join([f'Class {i}: {100 * acc:.2f}%' for i, acc in enumerate(test_class_accuracies)])}")
    # Save the model checkpoint
    # if epoch >= 4 and avg_test_loss<= avg_test_loss_best:
    if epoch >= 2:
        file_path_epoch = os.path.join(save_path, model_name + str(epoch+1)+'.pth')
        torch.save(model_, file_path_epoch)
# Out:
#   0%|          | 0/138 [00:00<?, ?it/s]
# Epoch[1] Avg Train Loss: 1.3251, Weighted Train Accuracy: 36.53%, Unweighted Train Accuracy: 31.30%
#  Avg Test Loss: 1.1894, Weighted Test Accuracy: 48.01%, Unweighted Test Accuracy: 43.54%
# Train Class Accuracies: Class 0: 3.15%, Class 1: 61.17%, Class 2: 54.42%, Class 3: 6.46%
# Test Class Accuracies: Class 0: 22.43%, Class 1: 70.62%, Class 2: 54.69%, Class 3: 26.40%
#   0%|          | 0/138 [00:00<?, ?it/s]
# Epoch[2] Avg Train Loss: 1.0963, Weighted Train Accuracy: 53.51%, Unweighted Train Accuracy: 52.69%
#  Avg Test Loss: 1.0351, Weighted Test Accuracy: 58.06%, Unweighted Test Accuracy: 57.66%
# Train Class Accuracies: Class 0: 47.81%, Class 1: 52.71%, Class 2: 60.79%, Class 3: 49.43%
# Test Class Accuracies: Class 0: 48.60%, Class 1: 62.19%, Class 2: 57.91%, Class 3: 61.93%
#   0%|          | 0/138 [00:00<?, ?it/s]

# %%
model_ = torch.load(os.path.join(main_dir+'model_lex_I.pth'))
print(model_)
# Out:
# BLSTM_CLSblock(
#   (rnn): LSTM(768, 128, num_layers=2, batch_first=True, bidirectional=True)
#   (fc): Linear(in_features=256, out_features=4, bias=True)
# )

# %%
# Evaluate the model on the test set
model_.eval() # <-----------------------------
test_loss = 0
test_iter = 0
test_labels = []
test_preds = []

with torch.no_grad():
    for features, labels, seq_lengths in test_loader_lex:
        features = features.to(device)
        labels = labels.to(device)

        outputs = model_(features,seq_lengths) #<------------------
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        test_iter += 1
        
        _, predicted = torch.max(outputs.data, 1)
        test_labels.extend(labels.cpu().numpy())
        test_preds.extend(predicted.cpu().numpy())

avg_train_loss = train_loss / train_iter
avg_test_loss = test_loss / test_iter
weighted_train_accuracy = accuracy_score(train_labels, train_preds)
unweighted_train_accuracy = balanced_accuracy_score(train_labels, train_preds)
weighted_test_accuracy = accuracy_score(test_labels, test_preds)
unweighted_test_accuracy = balanced_accuracy_score(test_labels, test_preds)
train_class_accuracies = class_wise_accuracy(train_labels, train_preds, num_classes)
test_class_accuracies = class_wise_accuracy(test_labels, test_preds, num_classes)

# print(f"Epoch[{epoch + 1}] Avg Train Loss: {avg_train_loss:.4f}, Weighted Train Accuracy: {100 * weighted_train_accuracy:.2f}%, Unweighted Train Accuracy: {100 * unweighted_train_accuracy:.2f}%")
print(f" Avg Test Loss: {avg_test_loss:.4f}, Weighted Test Accuracy: {100 * weighted_test_accuracy:.2f}%, Unweighted Test Accuracy: {100 * unweighted_test_accuracy:.2f}%")
# print(f"Train Class Accuracies: {', '.join([f'Class {i}: {100 * acc:.2f}%' for i, acc in enumerate(train_class_accuracies)])}")
print(f"Test Class Accuracies: {', '.join([f'Class {i}: {100 * acc:.2f}%' for i, acc in enumerate(test_class_accuracies)])}")
# Out:
#  Avg Test Loss: 0.9369, Weighted Test Accuracy: 63.13%, Unweighted Test Accuracy: 63.18%
# Test Class Accuracies: Class 0: 62.62%, Class 1: 65.00%, Class 2: 61.66%, Class 3: 63.45%

# %%
file_path_epoch = os.path.join(save_path, model_name + str(epoch+1)+'.pth')
torch.save(model_, file_path_epoch)

# %% [markdown]
# ### **Reslut for Lexical Only:**
# **Train Results:**
#
# | Model | Train Loss | Weighted Accuracy | Unweighted Accuracy | Angry Acc. | Happy Acc. | Neutral Acc. | Sad Acc. |
# |-------|-----------|------------------|---------------------|------------|------------|--------------|----------|
# | Last Block (e=8/10) | 0.6268 | 76.49% | 76.50% | 78.63% | 78.26% | 74.74% | 74.38% |
# | Avg. Pool (e=9/10) | 0.7926 | 70.70% | 70.29% | 71.65% | 68.73% | 75.71% | 65.08% |
# | Attention based (attention layer size - 64) (e=7/10) | 0.5780 | 77.65% | 77.60% | 79.53% | 76.74% | 78.86% | 75.28% |
#
# Note: The categorical names used are: Angry, Happy, Neutral, and Sad.
#
# **Test Results:**
#
# | Model | Test Loss | Weighted Accuracy | Unweighted Accuracy | Angry Acc. | Happy Acc. | Neutral Acc. | Sad Acc. |
# |-------|-----------|------------------|---------------------|------------|------------|--------------|----------|
# | Last Block (e=8/10) | 0.9218 | 65.04% | 64.03% | 53.74% | 64.06% | 71.31% | 67.01% |
# | Avg. Pool (e=9/10) | 1.0551 | 62.68% | 60.56% | 52.34% | 70.31% | 67.83% | 51.78% |
# | Attention based (attention layer size - 64) (e=7/10) | 0.9797 | 63.59% | 61.59% | 54.67% | 70.00% | 68.90% | 52.79% |
#
# Note: The categorical names used are: Angry, Happy, Neutral, and Sad.

# %% [markdown]
# First Block :
#     1. Epoch[7] Avg Train Loss: 0.6517, Weighted Train Accuracy: 75.52%, Unweighted Train Accuracy: 75.71%
#     2.  Avg Test Loss: 0.9369, Weighted Test Accuracy: 63.13%, Unweighted Test Accuracy: 63.18%
#     3. Train Class Accuracies: Class 0: 81.44%, Class 1: 76.89%, Class 2: 72.64%, Class 3: 71.88%
#     4. Test Class Accuracies: Class 0: 62.62%, Class 1: 65.00%, Class 2: 61.66%, Class 3: 63.45%

# %% [markdown]
# 1. Why the last block method performed better?
#     1. Shorter sequences show BLSTM able to capture most of the utterance context in the last block. So the last block has most of the information. But since we have a BLSTM model the other blocks output would also have the context to the entire utterance so averag pooling should also work. But maybe focusing on just one block's output makes it easier for the model to optimize weights sice we have a start and end token that are same across all the samples. It was also evident as when we didnt use the start and end tokens all the three models performed worst and the last block output method didnt do as good.
#     2. Something to do with BERT
#     3. Large feature input size so overfitting is possible. The more complex attention model overfits more compared to the simepler non attention based model.

# %% [markdown]
# # END

# %% [markdown]
# ## Multimodal

# %% [markdown]
# 1.  Use the pretrained acoustic and lexical model and fuse (by concatenation) there BLSTM pooled output  to get multimodal representation that can then be passed thorugth a linear layer for classification.
# 2. Fusion using GMU attention

# %% [markdown]
# 1. Lexical and acoustic model with average pooling as input.
# 2. Concatenates the pooled output from the two modalities to get a multimodal representaiton that is then passed through a softmax classifier.

# %% [markdown]
# ### Dataset

# %%
# data_pickel_path = ''

# %%
class IEMOCAP_mm(Dataset):
    def __init__(self, tokenizer, bert_model, mean, std, data_pickel_path, max_len=512):
        data = pd.read_pickle(data_pickel_path)
        self.x_l = data['trans_words']
        self.x_a = [np.array(samp_feat) for samp_feat in data['features']]

        y = data['emotion'].values
        self.label_encoder = LabelEncoder()
        self.y = self.label_encoder.fit_transform(y)

        self.tokenizer = tokenizer
        self.bert_model = bert_model
        self.max_len = max_len
        self.mean = mean
        self.std = std
        self.n_samples = data.shape[0]
        # self.spk = data['spk'] 

    def __getitem__(self, idx):

        # lexical features
        text = self.x_l[idx]
        word_ids = preprocess_text(text,self.tokenizer)
        word_ids = self.truncate(word_ids)
        embeddings = self.extract_embeddings(word_ids) 
        seq_size_l = len(word_ids)

        # acoustic features
        feat_a = torch.tensor(self.x_a[idx])
        if self.mean is not None and self.std is not None:
            feat_a = (feat_a - self.mean) / self.std
        seq_size_a = feat_a.shape[0]

        return feat_a,seq_size_a,torch.tensor(embeddings),seq_size_l,torch.tensor(self.y[idx])

    def truncate(self, sequence):
        if len(sequence) > self.max_len:
            return sequence[:self.max_len]
        else:
            return sequence # + [0] * (self.max_len - len(sequence))

    def create_attention_mask(self, input_ids):
        return [1 if token_id > 0 else 0 for token_id in input_ids]

    def extract_embeddings(self, input_ids):#, attention_mask):
        with torch.no_grad():
            input_ids = torch.tensor(input_ids).unsqueeze(0)
            # attention_mask = torch.tensor(attention_mask).unsqueeze(0)
            outputs = self.bert_model(input_ids)#, attention_mask=attention_mask)
            embeddings = outputs.last_hidden_state.squeeze(0).numpy()
        return embeddings

    def __len__(self):
        return self.n_samples

    def get_spk(self):
        return self.spk
        
    def get_encoder(self):
        return self.label_encoder

# %%
dataset_mm = IEMOCAP_mm(tokenizer, bert_model,mean,std,data_pickel_path)

# %%
feat = dataset_mm[0]
print(feat[0].shape,feat[2].shape,feat)
# Out:
# torch.Size([203, 65]) torch.Size([4, 768]) (tensor([[-0.7341,  0.1294, -0.3588,  ..., -0.0663, -0.8278, -0.3104],
#         [-0.7341,  0.1156, -0.3588,  ...,  0.4177, -0.3671, -0.3634],
#         [-0.7341,  0.0338, -0.3588,  ...,  0.6244,  0.1425, -0.2785],
#         ...,
#         [-0.7341, -0.0537, -0.3588,  ...,  0.9138,  0.4050,  0.1305],
#         [-0.7341, -0.0355, -0.3588,  ...,  0.1917,  0.3644,  0.2793],
#         [-0.7341,  0.0230, -0.3588,  ...,  0.5622,  0.7144, -0.0018]]), 203, tensor([[-0.1388,  0.2195, -0.0053,  ...,  0.0023,  0.0133,  0.3097],
#         [ 1.5709, -0.4490,  0.4407,  ..., -0.3449,  0.0637, -0.0286],
#         [-0.4176, -0.6967, -0.0282,  ...,  0.8575,  0.4115, -0.4271],
#         [ 0.8579, -0.0590, -0.1324,  ...,  0.1821, -0.6168, -0.2024]]), 4, tensor(2))

# %%
def custom_collate_fn_mm(batch):
    feat_a, seq_size_a, feat_l, seq_size_l, labels = zip(*batch)

    # Pad the sequences
    padded_feat_a = pad_sequence(feat_a, batch_first=True)
    padded_feat_l = pad_sequence(feat_l, batch_first=True)

    # Convert sequence lengths and labels to tensors
    seq_size_a = torch.tensor(seq_size_a)
    seq_size_l = torch.tensor(seq_size_l)
    labels = torch.tensor(labels)

    return padded_feat_a, seq_size_a, padded_feat_l, seq_size_l, labels

# %%
# from torch.utils.data import random_split
import random
# Set the random seed
random.seed(42)
num_samp = len(dataset_mm)
train_size = int(0.8 * len(dataset_mm))
test_size = len(dataset_mm) - train_size
train_indices = random.sample(range(num_samp), train_size)
test_indices = [i for i in range(num_samp) if i not in train_indices ]
print(train_indices)
print(test_indices)
batch_size = 32
train_dataset_mm = torch.utils.data.Subset(dataset_mm, train_indices)
train_dataset_mm = DataLoader(dataset=train_dataset_mm, batch_size=batch_size, shuffle=True,collate_fn=custom_collate_fn_mm)

test_dataset_mm = torch.utils.data.Subset(dataset_mm, test_indices)
test_dataset_mm = DataLoader(dataset=test_dataset_mm, batch_size=batch_size, shuffle=False,collate_fn=custom_collate_fn_mm)
# Out:
# [5238, 912, 204, 2253, 2006, 1828, 1143, 839, 4467, 712, 4837, 3456, 260, 244, 767, 1791, 1905, 4139, 4931, 217, 4597, 1628, 5323, 4464, 3436, 1805, 3679, 4827, 2278, 53, 1307, 3462, 2787, 2276, 1273, 1763, 2757, 837, 759, 3112, 792, 2940, 2817, 4945, 2166, 355, 3763, 4392, 1022, 3100, 645, 4522, 2401, 5149, 5066, 2962, 4729, 1575, 569, 375, 5417, 1866, 2370, 653, 1907, 827, 3113, 2277, 3714, 5207, 2988, 1332, 3032, 2910, 1716, 2187, 5308, 584, 4990, 5201, 1401, 4375, 2005, 1338, 3786, 3108, 2211, 5242, 4562, 1799, 2656, 458, 1876, 262, 2584, 3286, 2193, 542, 1728, 4646, 2577, 1741, 5369, 4089, 3241, 5266, 3758, 1170, 2169, 5513, 2020, 4598, 4415, 2152, 4788, 3509, 4780, 3271, 2965, 1796, 1133, 4174, 4042, 744, 385, 898, 1252, 5140, 1310, 3458, 4885, 520, 3152, 3126, 4881, 3834, 4334, 2059, 4532, 94, 938, 4398, 2185, 5250, 2786, 913, 2404, 3561, 1295, 3716, 26, 2157, 4100, 1463, 4158, 871, 5122, 2444, 5234, 5365, 4988, 1629, 5393, 3063, 1323, 4418, 4344, 4, 4906, 2655, 4002, 159, 916, 2973, 2519, 1961, 474, 1973, 4647, 5469, 701, 3981, 566, 4363, 1030, 1051, 3893, 4503, 1352, 2171, 4322, 4969, 3466, 1735, 4417, 1647, 2553, 3268, 3059, 3588, 4239, 3698, 991, 2030, 1840, 524, 2769, 172, 4819, 4537, 1885, 4820, 1804, 58, 581, 5169, 482, 1875, 552, 257, 2706, 580, 4211, 1949, 2281, 3976, 1755, 5325, 1083, 4677, 4720, 3872, 1990, 3874, 3334, 1559, 772, 794, 3531, 2902, 3469, 3367, 3825, 443, 806, 496, 3298, 2779, 895, 2036, 1569, 1558, 4393, 3675, 1148, 5508, 1503, 5295, 3789, 2046, 617, 3630, 4508, 802, 414, 4428, 120, 764, 1936, 1362, 3329, 3978, 3943, 1751, 3285, 480, 1348, 3104, 17, 3198, 2172, 3727, 2336, 3465, 4552, 3986, 1268, 1555, 2430, 1783, 479, 4744, 4441, 499, 2569, 468, 410, 4785, 3905, 4119, 4350, 1289, 465, 4160, 656, 1522, 561, 4874, 556, 1926, 3307, 982, 4666, 2016, 4742, 4870, 325, 5073, 671, 3434, 4781, 4630, 4282, 2591, 2136, 1673, 2573, 1955, 2175, 3242, 1072, 2457, 3745, 2590, 594, 76, 3754, 5088, 4612, 819, 600, 4404, 1746, 4144, 5239, 1085, 2859, 563, 2001, 3027, 2334, 1292, 3589, 4450, 2478, 5010, 4333, 64, 4543, 2452, 848, 1100, 5475, 945, 876, 5381, 5485, 2231, 2308, 4954, 1725, 2808, 1667, 2162, 4140, 5349, 2057, 416, 756, 5279, 2266, 361, 29, 2732, 1071, 2145, 5355, 3619, 4519, 3503, 4594, 79, 5347, 616, 1221, 4469, 295, 3024, 4771, 4526, 1213, 3520, 1044, 342, 2525, 2987, 326, 2931, 1720, 2044, 842, 2897, 4586, 5249, 5084, 1266, 1939, 1331, 1450, 3377, 203, 1469, 2721, 3372, 2032, 5377, 1304, 885, 3133, 317, 3855, 1822, 1634, 3770, 2864, 2500, 1864, 1826, 193, 1582, 3264, 2689, 2282, 568, 2286, 2876, 4173, 3274, 5472, 2712, 226, 944, 2139, 1462, 4756, 2174, 313, 888, 4887, 3559, 2831, 5225, 3574, 4966, 4189, 947, 3155, 4723, 1557, 2086, 363, 3572, 13, 4259, 4410, 1614, 2983, 3533, 573, 2704, 2571, 1020, 2460, 4154, 2533, 3345, 2672, 3296, 2422, 4541, 1042, 1571, 3444, 3105, 1425, 4662, 2465, 3326, 4488, 3, 2489, 2350, 1721, 3521, 4751, 5328, 2639, 3809, 5132, 3622, 1750, 4187, 3876, 1390, 694, 2324, 4222, 2745, 765, 1924, 2542, 5315, 1631, 1207, 200, 378, 5437, 3892, 596, 3730, 3395, 4715, 1592, 3145, 4049, 3273, 1998, 1208, 45, 873, 3482, 1792, 1440, 4243, 3805, 411, 4566, 2041, 994, 3739, 1092, 3806, 4351, 4578, 4877, 2599, 3625, 4135, 3495, 5021, 3652, 1303, 3888, 3686, 2123, 2025, 2271, 4270, 3969, 1959, 2249, 3603, 634, 2340, 1920, 2225, 2751, 2619, 4424, 660, 5399, 1235, 1894, 3137, 1251, 1752, 526, 3398, 3339, 2710, 4445, 3816, 3406, 510, 1694, 3441, 3190, 4784, 160, 4716, 3116, 3907, 48, 2881, 2446, 3194, 3432, 4409, 4473, 1806, 3999, 1797, 2235, 3570, 5248, 237, 3185, 2753, 3312, 5331, 3828, 1045, 5438, 220, 3227, 4848, 4623, 222, 687, 3511, 1111, 3782, 1488, 4974, 2131, 5026, 2681, 1733, 3724, 2677, 2764, 4884, 2279, 3453, 2066, 670, 3852, 158, 5354, 426, 2866, 1836, 562, 329, 254, 5150, 1633, 166, 1248, 1954, 1034, 3879, 937, 4620, 1785, 5012, 2099, 3021, 1374, 5379, 1341, 2548, 5092, 4740, 210, 2555, 4920, 3074, 3249, 1624, 622, 1989, 834, 2470, 5317, 4636, 336, 2844, 4364, 5404, 3035, 564 ...
# [0, 8, 11, 20, 22, 28, 30, 31, 32, 35, 36, 42, 47, 51, 54, 55, 61, 65, 69, 73, 75, 78, 80, 81, 84, 85, 86, 88, 95, 96, 97, 99, 102, 104, 105, 108, 117, 123, 128, 136, 139, 140, 143, 144, 146, 147, 155, 162, 165, 177, 180, 189, 191, 194, 197, 202, 224, 225, 228, 232, 238, 239, 264, 266, 271, 272, 274, 284, 285, 287, 289, 292, 293, 296, 297, 305, 310, 312, 320, 331, 339, 358, 362, 364, 377, 379, 380, 386, 391, 392, 393, 395, 397, 402, 406, 409, 417, 427, 431, 435, 437, 441, 442, 445, 451, 456, 460, 469, 470, 472, 473, 481, 483, 489, 490, 494, 505, 506, 514, 515, 518, 537, 558, 587, 589, 592, 593, 595, 607, 608, 619, 621, 630, 638, 639, 640, 641, 642, 648, 666, 675, 676, 680, 696, 703, 708, 711, 715, 722, 723, 725, 729, 741, 742, 743, 752, 757, 758, 769, 773, 776, 779, 785, 788, 798, 805, 809, 824, 829, 830, 831, 836, 850, 851, 854, 860, 862, 866, 868, 869, 870, 880, 882, 896, 899, 901, 902, 910, 911, 915, 917, 922, 930, 933, 936, 939, 956, 957, 960, 961, 989, 995, 998, 1011, 1017, 1019, 1027, 1029, 1039, 1040, 1041, 1043, 1049, 1052, 1060, 1061, 1062, 1063, 1067, 1069, 1075, 1080, 1081, 1086, 1088, 1089, 1090, 1091, 1102, 1103, 1105, 1107, 1116, 1121, 1123, 1128, 1131, 1136, 1144, 1146, 1147, 1156, 1157, 1166, 1168, 1177, 1181, 1187, 1190, 1191, 1194, 1202, 1205, 1214, 1223, 1224, 1226, 1234, 1239, 1244, 1249, 1254, 1258, 1259, 1272, 1278, 1279, 1293, 1300, 1301, 1312, 1318, 1324, 1326, 1327, 1337, 1339, 1344, 1357, 1366, 1367, 1369, 1375, 1376, 1381, 1384, 1389, 1391, 1396, 1400, 1403, 1404, 1408, 1415, 1422, 1433, 1446, 1452, 1455, 1461, 1466, 1487, 1493, 1512, 1513, 1515, 1521, 1524, 1526, 1534, 1548, 1549, 1551, 1552, 1560, 1578, 1587, 1596, 1598, 1611, 1612, 1615, 1617, 1618, 1619, 1622, 1639, 1645, 1648, 1649, 1655, 1658, 1662, 1665, 1668, 1676, 1678, 1688, 1698, 1707, 1726, 1727, 1739, 1740, 1747, 1748, 1754, 1771, 1774, 1775, 1776, 1778, 1782, 1786, 1787, 1816, 1817, 1830, 1832, 1833, 1849, 1854, 1855, 1856, 1858, 1859, 1860, 1868, 1881, 1883, 1897, 1898, 1900, 1901, 1911, 1916, 1919, 1930, 1932, 1937, 1938, 1941, 1946, 1957, 1969, 1970, 1971, 1976, 1981, 1988, 1992, 1994, 2007, 2008, 2012, 2013, 2022, 2031, 2034, 2035, 2050, 2061, 2064, 2069, 2072, 2073, 2081, 2089, 2094, 2095, 2103, 2104, 2106, 2114, 2115, 2117, 2118, 2128, 2130, 2133, 2138, 2140, 2142, 2150, 2155, 2158, 2159, 2177, 2181, 2182, 2196, 2204, 2205, 2209, 2213, 2217, 2218, 2222, 2223, 2244, 2245, 2264, 2267, 2273, 2274, 2275, 2292, 2294, 2299, 2313, 2327, 2328, 2332, 2338, 2352, 2353, 2357, 2363, 2367, 2373, 2374, 2375, 2381, 2382, 2391, 2394, 2396, 2397, 2400, 2402, 2416, 2419, 2421, 2428, 2436, 2455, 2458, 2459, 2463, 2466, 2471, 2480, 2482, 2486, 2492, 2494, 2495, 2503, 2505, 2507, 2509, 2522, 2523, 2527, 2529, 2532, 2534, 2543, 2544, 2554, 2562, 2563, 2566, 2570, 2578, 2585, 2600, 2609, 2614, 2621, 2623, 2653, 2658, 2659, 2666, 2673, 2678, 2682, 2692, 2693, 2695, 2699, 2702, 2703, 2705, 2708, 2713, 2714, 2716, 2725, 2729, 2733, 2738, 2739, 2740, 2748, 2763, 2772, 2775, 2797, 2798, 2799, 2801, 2806, 2815, 2823, 2832, 2846, 2847, 2852, 2853, 2857, 2871, 2874, 2877, 2879, 2884, 2885, 2888, 2891, 2894, 2900, 2904, 2909, 2911, 2916, 2923, 2929, 2933, 2935, 2937, 2945, 2957, 2959, 2966, 2968, 2974, 2980, 2984, 2986, 2989, 2993, 2998, 2999, 3016, 3020, 3022, 3029, 3030, 3037, 3038, 3040, 3042, 3045, 3046, 3057, 3064, 3067, 3068, 3075, 3076, 3082, 3086, 3089, 3093, 3094, 3095, 3098, 3106, 3107, 3109, 3118, 3122, 3132, 3136, 3139, 3143, 3147, 3156, 3163, 3164, 3170, 3171, 3173, 3177, 3178, 3182, 3184, 3186, 3192, 3196, 3203, 3205, 3208, 3209, 3215, 3217, 3218, 3219, 3220, 3226, 3234, 3236, 3238, 3254, 3258, 3267, 3269, 3272, 3275, 3277, 3278, 3279, 3284, 3293, 3294, 3295, 3301, 3305, 3314, 3315, 3320, 3322, 3333, 3337, 3340, 3341, 3347, 3348, 3351, 3352, 3355, 3356, 3357, 3359, 3360, 3364, 3369, 3371, 3373, 3391, 3393, 3402, 3410, 3413, 3417, 3422, 3424, 3425, 3431, 3435, 3445, 3446, 3447, 3449, 3452, 3454, 3459, 3461, 3468, 3472, 3477, 3480, 3491, 3498, 3502,  ...

# %% [markdown]
# ### Multimodal models

# %%
input_dim_a,input_dim_l, hidden_dim,num_layers, num_classes = 65,768,128,2,4

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_acoustic = BLSTM_avg_pooling(input_dim_a, hidden_dim,num_layers, num_classes).to(device)
model_lex = BLSTM_avg_pooling(input_dim_l, hidden_dim,num_layers, num_classes).to(device)

# %%
# Load the pre-trained model
acoustic_model_path = "/content/drive/MyDrive/IITB_EE/CS772_project/model_acoustic_II.pth"
ptmodel_acoustic = torch.load(acoustic_model_path,map_location=torch.device(device))

# Load the pre-trained model
lex_model_path = "/content/drive/MyDrive/IITB_EE/CS772_project/model_lex_II.pth"
ptmodel_lex = torch.load(lex_model_path,map_location=torch.device(device))

# Load the state_dict, assuming you have the 'acoustic_model' variable
model_acoustic.load_state_dict(ptmodel_acoustic)
model_lex.load_state_dict(ptmodel_lex)
# Out:
# <All keys matched successfully>

# %%
# Extract the BLSTM directly from the model
blstm_acoustic = model_acoustic.rnn
blstm_lex = model_lex.rnn

# %%
# blstm_acoustic = acoustic_model['rnn']
# blstm_lex = acoustic_model['rnn']
# fc_a = acoustic_model['fc']
# fc_l = lex_model['fc']
# fc_mm = torch.nn.Linear(hidden_dim * 4, num_classes) 
# fc_mm.weight.data = torch.cat((fc_a.weight, fc_l.weight), dim=1)
# fc_mm.bias.data = fc_a.bias + fc_l.bias
